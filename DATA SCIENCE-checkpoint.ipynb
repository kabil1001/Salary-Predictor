# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("D:/Back up/Hackathon/Final_Train_Dataset.csv", encoding='utf-8')
train.shape
# Out:
# (19802, 9)

# %%
train['salary'].unique()
# Out:
# array(['6to10', '10to15', '15to25', '3to6', '25to50', '0to3'],
#       dtype=object)

# %%
train['salary'].value_counts()
# Out:
# 10to15    4500
# 15to25    4125
# 6to10     3533
# 0to3      3245
# 3to6      2824
# 25to50    1575
# Name: salary, dtype: int64

# %%
 train.isnull().sum(axis = 0)
# Out:
# Unnamed: 0                  0
# experience                  0
# job_description          4418
# job_desig                   0
# job_type                15005
# key_skills                  1
# location                    0
# salary                      0
# company_name_encoded        0
# dtype: int64

# %%
job_temp = train.dropna(subset = ['job_description']) # dropping the NAN values in the job_description column only
job_temp = job_temp['job_description'].tolist() ##picking the job description column from the temp data frame
len(job_temp)
# Out:
# 15384

# %%
import re
import nltk
nltk.download('stopwords')
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')
words = ['please','must','year','years','experience','exp','location','salary']
stop_words.extend(words)
def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub('[^a-zA-Z]+', ' ', str(doc))
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
job_word = [] # passing the job_description list in normalise_document user defined function 
for i in temp :
    temp1 = normalize_document(i)
    job_word.append(temp1)
len(job_word)
# Out:
# ['minimum good understanding ioc rules good analytical skills good',
#  'handled team atleast direct reportees mechanical diploma mechanical',
#  'effective communicator written spoken strong inter personal relationship',
#  'overall data engineering big data systems proficient understanding',
#  'chartered accountancy degree mba finance premier institute',
#  'willingness travel teacher training',
#  'managing fraud analytics knowledge across customer lifecycle candidate',
#  'qualified chartered accountant yrs post qualification',
#  'proven payroll executive specialist good knowledge legislation regulations',
#  'activities may required period time smooth functioning finance operations',
#  'manage large volumes structured unstructured data extract clean data make amenable',
#  'credit card banking domain knowledge across customer lifecycle candidate',
#  'software development leverage usage tools technologies like',
#  'knowledge big data concepts hands working hadoop pyspark including',
#  'job responsibilities finalization annual budgeting lrp periodic forecasting',
#  'masters ms computer science quantitative discipline preferred make sure',
#  'hands hadoop technologies hive tez hbase',
#  'performing financial ad hoc analysis relevant positions',
#  'work various stake holders understand business requirement software development',
#  'managing running campaigns facebook google adwords youtube online',
#  'design code test debug record programs proficient work top technical level every',
#  'setting privacy frameworks incorporating requirements relevant data protection',
#  'strong leadership mentoring skills minimum team leadership client management',
#  'ensure data required centralized dunning work finance accounting minimum',
#  'analyses data gathered performance tests eye towards application performance',
#  'good team handling exhibit excellent leadership qualities team mentoring',
#  'accurately timely preparation standard mis weekly monthly basis responding',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'life insurance reinsurance company renova preferred',
#  'masters ms phd degree related technical field distilling presenting complex',
#  'good people skills ability lead manage team output effectively total',
#  'knowledge functional test script design accenture technology powers clients',
#  'preparing documenting simple computer programmes models clearly defined',
#  'highly technical environment strong foundational knowledge',
#  'minimum working hubspot marketing platform user',
#  'implementing image analysis algorithms educational qualification doctorate masters',
#  'looking hands internet company track record',
#  'providing required technical support consultancy customers contractor architects',
#  'change governance role handling good communication knowledge',
#  'kubernetes commonly used tools kubernetes ecosystem e g',
#  'least dimensional modelling',
#  'basic knowledge website design development huge plus though',
#  'proficient least major scripting language proficient least virtualisation technology e g',
#  'bachelors masters degree ee related field hands ic design',
#  'coordinate functionality performance testing provide continuously improved product',
#  'collections across different cycles frontend recovery strategy',
#  'b development deployment tools maven jenkins nexus git e hands',
#  'reporting analysis market risk delivering quality output',
#  'ensure customers get maximum value client product leveraging full platform functionality',
#  'minimum extremely responsible good management',
#  'ca progressively responsible financial leadership roles hunger learn',
#  'job role analyse company financial performance include past',
#  'strong candidates prior software product development good understanding',
#  'relevant business research consulting',
#  'using applied mathematics business planning management',
#  'consultant ready short term long term travel across india india',
#  'provide ongoing feedback stakeholders bench utilization availability skills need',
#  'hands devops engineer strong technical proficiency public clouds',
#  'good coding knowledge role techno functional role open',
#  'minimum sap finance functional analyst implementation service',
#  'working jointly solution architects business consultants senior consultant',
#  'industry building operationalizing various machine deep learning models finance',
#  'leading large strategic projects programs technical capacity',
#  'knowledge using analytical tools analysing large datasets sas sql excel vba etc',
#  'job description big data capability team hiring technologists produce optimal',
#  'able identify implementable trends technologies add value business',
#  'manpower forecasting including capacity planning skills mapping inventory management formulate',
#  'exhilarating opportunity dynamic field analytics experienced modeler',
#  'working ba company create documentation whenever whatever',
#  'extensive analysis design development good verbal written communication',
#  'credit card banking domain knowledge across customer lifecycle candidate',
#  'excellent verbal written communication abilities effectively communicate technical',
#  'extensive providing consulting services expertise mapping business',
#  'good knowledge key machine learning terms understanding implication model outputs',
#  'governance itil framework pmp prince certification sap fi co certification end',
#  'developing maintaining enterprise scale solutions skill set solid understanding',
#  'training computer programming languages sql sas r python',
#  'candidate graduation english medium',
#  'good rtl vhdl verilog system verilog writing skills ability create environment',
#  'participate requirement understanding design discussion calls meetings strong exposure',
#  'developing real time low latency applications candidate willing work',
#  'engineering team looking big data engineer work would',
#  'mba ca hand evaluating b b',
#  'machine learning deep learning text mining computer vision',
#  'hunting role sales management selling enterprise',
#  'proven track record space services mobile wireless digital emerging',
#  'good problem structuring skills ability rapidly grasp new concepts industry ability prioritize',
#  'combining unmatched specialized skills across industries business',
#  'able spot high profit opportunities general info major listed equities caps',
#  'business analyst telecom business analysis enterrprise architecture togaf',
#  'strong working consulting solution planning effort estimations resource planning',
#  'daily monitoring reporting senior management key liquidity risk drivers internal',
#  'delivery per committed required dates strong working knowledge understanding technical',
#  'senior business analyst job responsibilities understanding needs multiple',
#  'cloud architect responsible delivering enterprise class cloud design solutions ey',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'expertise significant hands design development least big data',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'minimum five increasingly responsible information technology environment',
#  'software engineering management working',
#  'understanding balance sheet preferably inclination learn business finance',
#  'good knowledge internal auditing standards issued iia',
#  'purpose job start plus role plays key role',
#  'minimum three prior similar role strong academic background top',
#  'proven working data analyst business data analyst knowledge statistics',
#  'least proven work pitching clients good commercial business',
#  'currently seeking quantitative researchers relevant financial services',
#  'using applied mathematics business planning management',
#  'strong consulting skills demonstrated managing teams across functions geographies',
#  'masters degree computer science engineering mathematics top schools',
#  'leading team people minimum accounting',
#  'least analytics good written oral communication skills come',
#  'candidate would required work across verticals across geographies candidates',
#  'business side preferably revenue planning qualification ca full time mba',
#  'due diligence credit analysis customer application screening evaluation',
#  'related combination risk control audit data analytics',
#  'tech good knowledge polymer surfactant structure property relationship',
#  'envisioned expansion cii looking technology solutions optimize automate',
#  'desired relevant healthcare lifesciences pharmaceutical domain',
#  'areas responsibility description responsibility sales',
#  'least bfs industry specifically retail',
#  'preferred proven sales demands rigorous time bound sales process',
#  'credit card banking domain knowledge across customer lifecycle candidate',
#  'organizational project management skills ability multi task work several assignments',
#  'comfortable working day night shift note ca ca inter cs',
#  'develop document execute test plans assess integrity accuracy business processes',
#  'individual able effectively manage cross functional partners internal external',
#  'working android description professional resume',
#  'create maintain update vital information required time time regarding client plan',
#  'role level responsibility ensure projects executed efficient',
#  'good understanding science behind machine learning algorithms supervised unsupervised',
#  'able independently drive set hr processes sops hr analytics',
#  'analytical skills ability interpret data analysis results derive actionable insights rather',
#  'good knowledge hadoop ecosystem components services data ingestion cluster planning',
#  'employee engagement employee grievance activities mandatory able join us',
#  'possess strong analytical skills sound working knowledge excel',
#  'maximizing sales performance delivering exceptional customer taking',
#  'relevant work management consulting advisory',
#  'prior portfolio analysis monitoring driving strategic initiatives would',
#  'reading translating lease documents using online tools skills competencies',
#  'position design responsibility ensure product programs achieve design objectives',
#  'social networking social analytics tools knowledge fluency english positive',
#  'minimum total work media business consulting strategic planning role',
#  'success recruiting retaining high performance sales team demonstrated',
#  'knowledge omni channel marketing automation tools like adobe campaign responsys webengage',
#  'outstanding verbal written communication skills excellent project management',
#  'bring significant applying relevant technical knowledge least one',
#  'teach india nationwide movement outstanding college graduates working professionals',
#  'machine learning algorithms data mining techniques statistical',
#  'least yr analytics preferred candidates banking domain undertaken',
#  'deep understanding business needs talent required meet needs provides us',
#  'high potential candidates development project well support projects',
#  'hands functional skills',
#  'icwa qualified preferably looking candidates strong exposure',
#  'minimum site preparation bids types',
#  'professional software development c large scale multi',
#  'manage oversee daily operations finance accounting department candidate epc',
#  'minimum full life cycle software implementation projects salesforce architect',
#  'drive innovation identifying breakthrough opportunities solid ecommerce online',
#  'around confident sound communication skills ability coordinate',
#  'working team analysts common goal strong understanding',
#  'hands data modelling data analytics tools like sql tableau r python',
#  'machine learning deep learning text mining computer vision',
#  'desired relevant retail media domain hands',
#  'excellent opportunity work established company make telephone calls',
#  'advanced degree math computer science statistics physics related field high gpas',
#  'domain working fast paced consulting companies emerging technologies able',
#  'proficiency use devices data loggers light meters utility meters',
#  'knowledge services domains business process outsourcing systems',
#  'greetings experis hiring role senior manager',
#  'candidate expertise use setup various analytical online tools used',
#  'understands needs organization terms achieving maximum organizational performance',
#  'contributes various intellectual properties development thought leadership initiatives',
#  'fingent believe business software beautiful usable',
#  'strong translating business requirements prototype design addressing',
#  'produce required documents cast analytics adoption customer adapting reusing',
#  'building test lab setups preparing test plans test case development test',
#  'expert excel insert customer account data inputting text based numerical information',
#  'post graduate degree statistics finance mathematics engineering computer science preferred',
#  'group currently seeks person knowledge skill financial securities carry',
#  'required qualifications relevant working big data related tech',
#  'content creation including case studies knowledge base client faqs video storytelling',
#  'app install campaigns google play app store would big plus',
#  'layout pages per clients requirement specification within stipulated time good command',
#  'able create job postings articulate professional attention grabbing',
#  'yrs candidates preferred retail fmcg airline',
#  'develop reliable cash flow projection process reporting mechanism includes minimum cash',
#  'strategy consulting role preferably industry along areas',
#  'software development development life cycle good understanding major',
#  'looking young entrepreneurial individual good analytical skills',
#  'developing integrated solutions involving process data technology business',
#  'prior start ups highly desirable required marketing growth',
#  'good analytics skills problem solving skills extensive testing android apps',
#  'cyber security sought domain nasscom projects requirement million',
#  'comfortable functioning broadly positioned highly diverse consulting firm',
#  'making quick high quality decisions complex case scenarios',
#  'minimum global financial services company prior accounting audit management',
#  'candidates digital marketing agencies high paced ecommerce companies great',
#  'identify deploy technical skill sets resource levels systems deliver',
#  'good understanding software development concepts test planning',
#  'critical thinker aptitude working ambiguous technical problems',
#  'qualified chartered accountant yrs post qualification',
#  'manage delivery execution analytics services top tier clients fpa domain',
#  'good understanding common design patterns architecture principles design reliable scalable',
#  'multi unit retail restaurant concepts preferred manager director',
#  'deep core financial analytics risk collections marketing plus bachelors',
#  'payroll accounting analytics end end payroll processing activity',
#  'managing fraud analytics knowledge across customer lifecycle candidate',
#  'aptara copy editors rigorously follow publishers house style sheet optionally apply copy editing',
#  'team player good stakeholder management certification analytics added',
#  'candidate strong scripting worked data driven key word driven',
#  'incumbent operational understanding includes classical regression statistical methods like',
#  'strong sql skills including query optimization required recommendation systems',
#  'one iims modeling sas credit risk',
#  'possess extensive primary secondary research skills generate highly readable',
#  'least investment required preferably knowledge factor research',
#  'detailed understanding local development control regulations good network architects',
#  'desired relevant retail media domain hands',
#  'inside sales lead generation cold calling response management',
#  'institute personal leadership ipl founded columbia business school professor hitendra wadhwa',
#  'refine processes supply side tech workflows increase efficiency ensure better',
#  'ofrelevant embedded programming writing test routines performing qualification',
#  'preferably consumer facing application development large scale enterprise',
#  'managing integration projects high volume data transfers excellent problem solving',
#  'leading teams size members good knowledge statistical techniques',
#  'balance practical mindset creative business acumen lead people complex',
#  'equity research analyst institutional broking interaction maintaining relationships',
#  'liaison coordinate business head leadership team ensure corporate initiatives',
#  'projects within digital space iot ai cloud services e commerce etc post',
#  'understanding metrics like conversion rate visits click rate required well',
#  'good problem solving analytical skills software development',
#  'responsible supporting architectural direction component design enterprise solutions built',
#  'required company provide guest house accommodation till settling good',
#  'minimum alteast data analytics retail banking loan cards academic',
#  'exciting leadership job opportunity leading global group strong foothold specialty',
#  'define product features work closely design engineering teams end end',
#  'natural language processing techniques text analytics strong plus',
#  'full stack development android applications least',
#  'relevant work supporting sales team engagement managers working',
#  'development java scala python writing',
#  'working multiple brands digital media industry',
#  'responsible advising guiding big data analytics technology adoption programme within',
#  'minimum three prior similar role strong academic background',
#  'design patterns design level situations desired candidate',
#  'assess learning needs ensure training needs aligned business',
#  'solid understanding descriptive analytics techniques building guided analytical',
#  'understanding agile software development life cycle processes devops',
#  'shall responsible design various systems useful test radars simulators active p',
#  'seo digital marketing graduate technical',
#  'sourcing managing content development publishing makes evident good technical',
#  'good understanding general ledger relation sub ledger processes accounting workflow c',
#  'good fluent communication skills proficiency ms office knowledge handling',
#  'candidate open stack hands machine learning good',
#  'predictive prescriptive statistical analysis working within linux',
#  'looking candidate brings strong problem solving skills combination solid',
#  'working supply chain analytics project delivery hands data',
#  'inclined market research industry curiosity learn stock',
#  'proficient designing developing testing performance tuning debugging various biztalk server',
#  'controlling information technology budget deriving positive outcomes tech information',
#  'project management similar functional role schedule meetings cr',
#  'work least analytics role hands excel sql',
#  'person show ownership willing take things closure products person',
#  'support ux team providing business requirement specifications design workshop notes minutes',
#  'least leading delivery teams large scale full life cycle',
#  'writing proposals coming solutions address customers business needs',
#  'statistical modeling risk analytics position',
#  'qualifications solving complex data problems reusable efficient scalable code',
#  'designing building cloud native applications well azure cloud migration',
#  'candidate expected apply knowledge java spring develop tier architecture',
#  'requred skill set required sas',
#  'purchasing managers logistics supply chain procurement manager required australia canada',
#  'leading teams size members good knowledge statistical techniques',
#  'hands statistical techniques like logistic regression clustering segmentation etc',
#  'handling marketing budgets forecasting reporting results outstation candidates first',
#  'fresher graduates less may apply skills required',
#  'demonstrable equity research financial analysis credit analyst corporate loans',
#  'hands technical development maintenance complex java gui components using',
#  'hands data modelling data analytics tools like sql tableau r python',
#  'ensure positive customer csat first call resolution minimum average',
#  'working team analysts common goal strong understanding',
#  'good communication presentation skills local knowledge',
#  'hands project life cycle methodologies like waterfall hybrid agile scrum etc good',
#  'need find correct balance page optimization page optimization paid',
#  'work preparation investment notes financial modelling driving',
#  'done integration sas ebi platform third party tools consultant ready',
#  'good handling compliance issues taking actions treating customers',
#  'position someone loves writing screenshot based technical',
#  'designing implementing transportation optimization models focus volume',
#  'senior quality assurance engineer understand clients needs identify fit within',
#  'participate response rfps supporting sales team required industry',
#  'software development accounting finance sql oracle sql',
#  'minimum relevant exposure seo marketing business development fabulous',
#  'previous sales services ability achieve high conversion rates',
#  'good excel min months team leader preferred',
#  'sas mandatory use sophisticated statistical techniques develop scorecards customer',
#  'senior position working seo expert least managerial role',
#  'post graduate degree finance accounting similar streams months relevant',
#  'willingness stretch work beyond role boundary strong work ethic positive',
#  'strong sas r least sas sql mandatory analytical',
#  'performing root cause analysis internal external data processes answer',
#  'good knowledge handling marketing campaigns social media measure',
#  'advisory related internal audit external audit big post',
#  'implemented least sql bi projects part designing requirements gathering',
#  'complete application development life cycle including requirements gathering analysis',
#  'hr analytics hris preferably consulting firm preferable education computer',
#  'goal driven focused helping clients meet requirements developing answers',
#  'supporting team problem definition issue identification work plan development using',
#  'experienced motivated expert data analytics hand perform demand',
#  'credit underwriting credit operation credit officer credit manager loans',
#  'timing analysis sign timing convergence execution aspects',
#  'posting driven business requirement education qualification required mca',
#  'required qualifications b com com mba financeexperience finance accounting reporting',
#  'manage campaign expenses estimate monthly costs achieve maximum roi spend',
#  'applicant strong analytical logical problem solving skills ability lead',
#  'inspire motivate develop lead team technology product management professionals build',
#  'candidate amv drug product drug substance',
#  'professional combination telecommunication sector',
#  'knowledge creating mobile views reports dashboards minimum',
#  'ability work effectively cross functional team environment willingness constantly',
#  'software development achieving maximum productivity team members',
#  'controlling information technology budget deriving positive outcomes tech information',
#  'good knowledge understanding web service apis integration purposes skills required',
#  'able influence change effectively manage stakeholders across zones',
#  'creating test deliverables test strategies test scenarios metrics',
#  'possess good people skills smart individual solution oriented approach',
#  'candidates enzyme based organic transformation preferred good knowledge',
#  'minimum proficient technology stack concepts',
#  'prioritize required technology change post go live release ensure initiatives remain time',
#  'willingness ability learn adopt new programming languages programming',
#  'commercial cost practices vendor development manufacturing processes',
#  'extensive using sas r python analyse solve business problems',
#  'defining corporate wide data strategy data governance',
#  'done marketing cyber security software services company required',
#  'looking fico functional sap fico consultant sap environment',
#  'well versed core cat modeling perspectives loss statistics use',
#  'posses excellent verbal written communication skills',
#  'built large scale data pipelines process millions events per day',
#  'required strong fund raising minimum',
#  'strong leadership mentoring skills minimum team leadership client management',
#  'post graduate degree statistics finance mathematics engineering computer science preferred',
#  'combine business expertise large scale data analysis visualization advanced',
#  'quality testing content based products good focus delivering high',
#  'core banking signature front end application systems assist achieving',
#  'special role requirement ability understand potential risks work environment preferred liaise',
#  'good communication skills candidate capability technical understanding',
#  'distinguished client looking individual hungry grow leveraging extensive',
#  'good understanding mobile development life cycle android sdk',
#  'expert knowledge least one statistical soft wares sas sql r python excel',
#  'ux ui designer design develop innovative ux ui based solutions products',
#  'delivering products utilizing data science algorithms machine learning',
#  'excellent research skills analytical skills client interfacing skills presentation skills',
#  'engineer premier engineering college e lean six sigma',
#  'female candidates candidate possess minimum warehouse behavioral',
#  'proven working data analyst business data analyst knowledge statistics',
#  'greetings p moller maersk integrated transport logistics company multiple',
#  'performance tuning analyst roles primarily performance engineer test',
#  'yrs relevant however basis candidates skill sets expertise ok',
#  'extremely good coding knowledge hands anesthesia e pathology denials',
#  'distributed micro service design principles service oriented architectures',
#  'strong client handling strong client handling',
#  'production application systems monitoring performance optimization root cause',
#  'one critical delivery channels across products role holder recommend',
#  'conduct global primary secondary research preparing reports comprising market',
#  'candidate excellent written verbal communication skills individual performer',
#  'least investment banking hedge fund capital markets fund accounting',
#  'developing communicating translating sales business strategy action plans',
#  'statistical programming languages example sas using business',
#  'developing strong metrics driven team attention quality quantity knowledge',
#  'management preferably production service environment including',
#  'least manufacturing company turnover rupees crores',
#  'least working analytics least working analytics',
#  'interact customers external parties whenever required relevant',
#  'developing workbooks multiple data sources using data blending hands',
#  'requirement gathering database designing coding unit testing maintenance etc skills required spring',
#  'good time management skills able meet expected deliverables extensive',
#  'digital strategy driving maximum roi industry best numbers digital',
#  'comply good software engineering principles including limited standard coding',
#  'project management consulting digital marketing business research',
#  'practical sas etl data processing data analytics required qualifications',
#  'able estimate time tasks assigned provide periodic status updates involved',
#  'hi exciting job opportunity senior strategic finance analyst chennai',
#  'minimum marketing executives likely great deal',
#  'minimum business analysis related field resource',
#  'roles responsibilities industry business data analysis involved',
#  'yrs relevant pricing analysis mandate shift night shift summary',
#  'looking analytics professionals atleast analytics',
#  'good exposure ms excel power point presentation basic knowledge ms',
#  'heading information technology team institutional equities business mosl covering',
#  'cm owns processes timetable required regular finance',
#  'seo executive qualification ug pg work',
#  'work product managers across business build user stories based technical requirement',
#  'good integrating servicenow external application using different methods soap',
#  'sgs worlds leading inspection verification testing certification mnc',
#  'demonstrated handling cleaning merging manipulating analyzing large',
#  'good problem solving analytical skills software development',
#  'individual also work well pressure meet ongoing overlapping deadlines within',
#  'role keen eye detail excellent communication skills',
#  'pay slips send atleast one month payslips current previous organizations',
#  'java creating responsive application total overall',
#  'industry mis reports',
#  'hands statistical tools like sas r good knowledge r',
#  'responsibilities person likes share',
#  'supply inventory planning nit bits iit iim isb tier b',
#  'coordination ownership management information required global markets business',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'minimum hard core recruitment talent acquisition',
#  'presentation mmr qbr min preferably service',
#  'well versed current market trends terms new materials prices candidate',
#  'sound knowledge time series linear regression splines decision trees',
#  'direct sell clients meetings pitches identify needs drives client relationship',
#  'required qualifications customer service role',
#  'possess strong selling products services clients businesses',
#  'excellent interpersonal communication skills required given diverse nature operating landscape',
#  'clear understanding basic concepts database data integration data analytics sql',
#  'good financial controlling related analytical skills good knowledge advance microsoft excel',
#  'conceptualize tests collect analyze data identify trends insights order achieve',
#  'candidate able thrive entrepreneurial environment able clearly communicate',
#  'hands independently handles projects facilitation skill',
#  'hands delivering results driven analytics solutions proven',
#  'iterative agile development practices preferred candidates immediate interview',
#  'relevant work required willing work shifts x work',
#  'working popular keyword tools google wordtracker keyword discovery etc',
#  'good written verbal communications skills open minded good grasping',
#  'make sure candidate qualify checklist written relevant',
#  'net c along object oriented design strong candidates prior',
#  'combine rearrange data source documents required know mis report good written',
#  'liaise connectors ipcs developer seek required data analysis presentation',
#  'work functional teams analyze identify test cases identify test data requirement hands',
#  'good understanding procurement process including negotiation third parties minimum',
#  'good verbal email documentation skills worked landscape multiple',
#  'work home full part time virtual opportunities',
#  'developing andconsuming web services university degree bachelor engineering',
#  'least work administrative support role',
#  'knowledge working global services organisation working project',
#  'strong development either java j ee spring framework net exposure towards web',
#  'role challenging entrepreneurial nature bound bestow lot learning upon',
#  'good understanding campaign promotional offer measurement related metrics tracking',
#  'dear reader expanding market research team looking self',
#  'job responsibilities daily responsibilities duties compensation',
#  'batch tier ii colleges banking credit card domain good',
#  'minimum launching paid campaigns seo optimization saas',
#  'industry country business strategic databases like',
#  'handling integration multiple systems reporting using hana related integration',
#  'cotton analyst subject matter expert cotton trade analytics statistics strong',
#  'provided sales team strategic tactical marketing support required stand field',
#  'major deliverable would maintain healthy portfolio healthcare business minimum',
#  'iqor global managed services provider embedded flow product people',
#  'demonstrable developing successfully implementing digital marketing strategy',
#  'monitor key performance indicators engineering department take corrective action',
#  'good team handling exhibit excellent leadership qualities team mentoring',
#  'bull good verbal written communication skills bull work',
#  'masters doctoral degree specialization statistics mathematics finance',
#  'strong sense engineering craftsmanship takes pride code write believes',
#  'accenture technology powers clients businesses innovative technologies established',
#  'data modelling analytical engines big data retail banking saas campaign',
#  'working msoffice good communication skills written',
#  'team building management handling direct reports predictive modeling',
#  'senior analyst lead production client deliverables ranging',
#  'industry within auto home insurance industry ideally',
#  'analytics teams solving problems top global companies deep',
#  'r sql oracle preferred ability manage stakeholders mentor junior team members adept',
#  'ability understand formalize required end deliverables within defined time lines moodys',
#  'degree electrical engineer computer engineering computer science least asic',
#  'able independently handle seo campaigns work cross departmentally achieve goals',
#  'may small architectural changes required third key requirement',
#  'randstad hiring learning development coordinator one leading client',
#  'understanding premise cloud security strategies principles',
#  'individual able effectively manage cross functional partners internal external',
#  'atos operates brands atos atos consulting atos worldgrid bull canopy unify',
#  'strong communication skills candidate needs good communication skills written',
#  'able understand guide business head management important aspect',
#  'willing work night shift good comprehension analytical skills good using search',
#  'assist chairman inputs data required making strategic decisions',
#  'prime responsibility coordinate patch managers ensure seamless patch execution',
#  'along good analytical problem solving skills candidate strong communication skills',
#  'individual ability work effectively pressure without compromising',
#  'candidate hold either one full time degree e experienced handling project',
#  'team member activities raise funds monitor full implementation projects',
#  'btech mba sales management knowledge data analytics tools bi',
#  'bex query designer workbooks bex analyzer using conditions structures',
#  'pharmacovigilance track adverse event reports received completed',
#  'successfully managing internal external stakeholders delivering',
#  'frontend engineering skills passion web analytics knowledge tag management',
#  'essential duties responsibilities executive assistant chairman able',
#  'candidates possess excellent written verbal communication skills relevant',
#  'machine learning statistics optimization related fields deeper',
#  'core responsibilities ensure proper financial accounting costing taxation',
#  'successful candidate possesses superb business judgment proven record successful',
#  'working client facing technical service environment preferably supporting web based',
#  'overall digital marketing tag management campaign analytics web',
#  'provide advisory consultation customers marketing purchasing property best deal',
#  'proven working yrs digital marketing highly creative',
#  'working financial data economic data knowledge',
#  'collaborate designers improve user b c social media google adwords',
#  'working large data sets collection analysis processing good',
#  'candidates available personal',
#  'search engine marketing sem search engine optimization seo',
#  'capturing sentiments feedback customers multiple sources like websites',
#  'management consulting corporate strategy',
#  'primary qualitative market research agency prerequisite',
#  'personal visits corporate involving presentations company ensuring maximum customer',
#  'utilize strong analytical ability evaluate end end customer across multiple channels',
#  'hands advance machine learning techniques problems regression forecasting',
#  'one iims modeling sas credit risk',
#  'graduate post graduate working client servicing operations account',
#  'managing fraud analytics knowledge across customer lifecycle candidate',
#  'audit providing necessary information required statutory group tax auditors good',
#  'least playing implementation consultant role across',
#  'creating workflows flowcharts specifications diagrams business requirement document adept',
#  'p c domain knowledge across customer lifecycle candidate',
#  'retail domain knowledge across customer lifecycle candidate',
#  'strong data processing data mining social network analysis text mining',
#  'minimum hard core domain preferably general insurance sector',
#  'matches',
#  'team player good stakeholder management certification analytics added',
#  'bachelors advanced degree masters quantitative discipline demonstrated aptitude',
#  'strong implementing large projects preferably worked global projects strong',
#  'working technical business analyst role minimum',
#  'previous working manufacturing organization exposure sap',
#  'developing productive working relationships key customers',
#  'healthcare retail mail order pharmacy medicare part pharmaceutical benefits',
#  'good hands statistical techniques like regression segmentation etc',
#  'ideal candidate customer facing roles success leading deep technical',
#  'digital strategy driving maximum roi industry best numbers digital marketing',
#  'relevant building large scale machine learning deep leaence',
#  'managing facilitating collaboration among diverse skill sets including designers',
#  'need understanding depth knowledge luxury brands candidate',
#  'required strong commitment quality accuracy getting thing done correctly first',
#  'minimum hard core recruitment talent acquisition indepth',
#  'assess accurately time required completing tasks consultant deep understanding sap',
#  'overall hr e g hr analytics candidate',
#  'least building handling large scale systems deep working',
#  'marketing communications desired skills scrappy',
#  'candidate adept various aspects development using web frameworks including',
#  'financial services industry quantitative field preferably',
#  'yrs building backend applications web apps analytics',
#  'ideal candidate application administration sas application',
#  'creating project plan including aspects schedule requirements quality etc',
#  'marketing analytics business analytics statistics related field',
#  'e commerce last mile business finance logistics particular prior',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'work closely marketing team designing various campaigns activities provide required',
#  'hands working general ledgers gst return filing proficient erp',
#  'call digital marketeers marketing position environment offers',
#  'looking sas professionals good campaign management data',
#  'goal driven focused helping clients meet requirements developing answers',
#  'team management mentor ship good resolving conflicts',
#  'required minimum skills required good analytical skills',
#  'minimum quantitative finance data science distributed',
#  'create product roadmap plan user lead go market activities work',
#  'machine learning domain preferably life sciences healthcare task',
#  'prior teaching preferred',
#  'team tasked come multiple visualization use cases using existing external data',
#  'elevated stations design project',
#  'hands using cloud platform provided big data non big data services',
#  'b b projects initiatives looking candidates',
#  'proficient adobe suite photoshop',
#  'excellent verbal written communication abilities effectively communicate technical',
#  'big data stack including multiple open source tools work together hive hbase r',
#  'bonus points high level language programming python ruby jvm languages like',
#  'credit card banking domain knowledge across customer lifecycle candidate',
#  'ability travel within country international within short notice wherever required possess',
#  'banking nbfc space least recent yrs education',
#  'min sap mm min domain knowledge good',
#  'occasionally participate customer demos provide inputs wherever required looking',
#  'candidates manufacturing industry also considered subject related key',
#  'position entry level research position role deliver',
#  'topics venue hyper personalization mobility driving lot innovation',
#  'candiate utilize business knowledge related financial services',
#  'digital advanced analytics using popular analytics',
#  'ensuring negative findings variances found whilst conducting cross checks addressed',
#  'google analytics various analytical tools content writer required cosmetics',
#  'curriculum curated industry veterans delivering cutting edge',
#  'leading geographically distributed culturally diverse work groups',
#  'candidate able showcase strong existing relationships select customers partners',
#  'role responsible following areas deliver budgeted sales gross',
#  'responsibilities include limited understand business problem detail',
#  'demonstrated requirements analysis design using standard tools techniques',
#  'demonstrated ability manage solution based sales multiple levels customer organization',
#  'worked oss bss applications like billing crm provisioning mediation interconnect',
#  'consulting background relevant proficient customer analytics',
#  'identifying deal across various sectors ideal candidate would currently',
#  'candidate know type content works best platform optimizing content accordingly',
#  'support full data life cycle project requirement identification prototyping design',
#  'available act sme mentor team resolve complex tickets',
#  'written verbal communication including technical writing skills implement advanced',
#  'least two similar technical role min hardware',
#  'understanding econometric statistical modeling analysis techniques',
#  'candidate passion latest developments front end technologies well',
#  'similar role preferably client side good managing medium',
#  'related working expect',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'vast microsoft dynamics crm since version dynamics crm',
#  'writing executing integration test plans test scenarios strong',
#  'prepare financial statements assess internal controls analyze prepare monthly',
#  'join talented diverse team covering nationalities variety backgrounds',
#  'credit risk assessment credit research education ca mba',
#  'drive implementation sale enablement programs roadshows events zones etc',
#  'education good communication',
#  'good analytical logical skills working knowledge dbms data mining preferred fresh graduate',
#  'analyzing data draw business relevant conclusions data visualization techniques',
#  'minimum advance analytics technical skills r python machine',
#  'comfortable communicating high level political figures government policy',
#  'design create maintain provide required reports answers willingness put hours',
#  'ideal candidates extensive delivering native universal mobile enterprise apps',
#  'worked large data sets excel ms access sql server similar database',
#  'evaluate risks associated particular proposed transactions required sound knowledge',
#  'knowledge iso systems work ts company added advantage',
#  'handling high volumes report requests need',
#  'good written verbal communication skills work home full part time virtual opportunities',
#  'hi aptara currently hiring profile process associate man',
#  'bpo voice process required able work rotational shifts required skills',
#  'strong preference previous work start post qualification',
#  'bs computer science related field preferred working web development',
#  'certification ccna siem certification',
#  'terms temporary possibility permanent candidates mumbai apply',
#  'strong monitoring real time server performance cover cloud',
#  'good communication strong interpersonal skills ability interact stakeholders',
#  'database performance tuning sql query optimization data processing',
#  'establish good rapport team qualification graduate mathematics statistics',
#  'customer oriented obsessed providing highest quality product',
#  'good communication presentation skills local knowledge',
#  'ibm certified data modeling framework manager author',
#  'credit card banking domain knowledge across customer lifecycle candidate',
#  'developing operating large scale cloud based distributed applications',
#  'building list data mining proficient business e mails excellent written verbal',
#  'experienced managing infrastructure services databases deployed cloud service',
#  'focused financial modeling project appraisal due',
#  'willingness ability learn new things good secretarial skills willingness follow',
#  'terrific written verbal communication skills business development',
#  'requires minimum working training microsoft sql server technology',
#  'understand appreciate financial ratios working capital requirement different',
#  'proficient translating unstructured business problems abstract mathematical framework',
#  'post ca fmcg industry well versed',
#  'industry hands scripting python bash shell',
#  'commitment continuous process improvement required required',
#  'software development using oo methodologies designing software solutions',
#  'hands end end information risk management lifecycle working global',
#  'help sales bd good sales capture origination skills selling skills however primary',
#  'develop flair exploratory experimental side role required tease interesting',
#  'minimum creating high quality content software services product based',
#  'least relevant industry minimum program',
#  'technical competencies sas py',
#  'professional java j ee based server side application developing troubleshooting',
#  'knowledge seo smo trends methods best practices monitoring search engine',
#  'multi unit retail restaurant concepts preferred manager director',
#  'strong candidates prior software product development team management',
#  'building scalability testing automation enterprise level coding build',
#  'exposure hands analytics platforms like anaconda jupyter advanced modeling',
#  'creating data visualizations self driven ability take',
#  'developing small foot print vision algorithms mobile platforms phd mtech',
#  'yrs work preferably credit rating credit appraisal financial research',
#  'b able work independently work cross functional client facing teams within',
#  'good knowledge labor law proficient ms office primarily excel proven work hr',
#  'minimum three prior similar role strong academic background',
#  'staff deliver technology infused omni channel customer management marketing',
#  'google analytics various analytical tools content writer required cosmetics',
#  'business system analysts bsa role handles wide array responsibilities given time',
#  'job summary position responsible providing support sales analysis',
#  'ui ux siebel knowledge qualifications graduate',
#  'good communication skills work global teams customers',
#  'work closely development teams ensure solutions designed customer user',
#  'qualification ca mbf graduate',
#  'candidate proven track record interacting varied teams preferable across various',
#  'problem solving ability analytical skills',
#  'recruitment decisions based solely qualifications skills knowledge',
#  'role handle rewards recognition compensation benefits',
#  'able develop complete link building strategy built least quality',
#  'proven working data analyst business data analyst knowledge statistics',
#  'analytical practical knowledge gst customs indirect tax laws',
#  'familiar consulting frameworks evaluation metrics opportunity mapping market entry',
#  'candidate would need understand online advertising market technologies involved',
# ...
#  'good knowledge p l balance sheet skill sets required us accounting',
#  'takes ownership makes required judgements whenever necessary enjoys learning building',
#  'good analytical skills mis number crunching reporting internal external customers',
#  'candidate understand apply industry best practices standards processes procedures',
#  'advanced degree math computer science statistics physics related field high gpas',
#  'good interpersonal negotiation skills ability effectively influence various levels management',
#  'sap least end end implementation support projects',
#  'hr data analyst bfs yrs hr reporting analyst working workday xactly',
#  'leading architecture transformation traditional next gen data analytic technology',
#  'worked large data sets excel ms access sql server similar database',
#  'data analyst data cleaning data transformation metrics optimization',
#  'bring significant applying relevant technical knowledge least one',
#  'common data science toolkits r weka numpy matlab etc',
#  'engineering graduates premium technical institute full time mba pgpm ipmx pgpx pgpex',
#  'export sales educational qualification diploma degree engineering',
#  'female graduates mba pgdm management executive assistant',
#  'client world class rating agency days working organization qualification',
#  'responsibility candidate hold bachelor degree engineering',
#  'holding relevant building model within banking domain good stress',
#  'good understanding software development best practices agile scrum debugging troubleshooting',
#  'total hands work software development hands',
#  'negotiating contracts directly clients including review drafting research',
#  'business analysts may reports may junior business analysts support',
#  'projects initiation till closure including finance management leading complete sdlc life cycle',
#  'knowledge hands optimization software run high end servers well low',
#  'ar callers yrs looking dayshift also apply days working',
#  'past selling high volume long term deals would added advantage prior',
#  'least mentioned jd pune requirement want someone',
#  'b tech mba top tier institutes strong quantitative background',
#  'agile software development methodology test driven development designing',
#  'work prevent non conformances customer complaints concession coordinate operations',
#  'web programming preferred proficient understanding code versioning tools git',
#  'minimum work fluent written verbal communication skills plus',
#  'knowledge advanced excel vlookup hlookup pivot tables advance filters filters',
#  'good understanding software development concepts test planning',
#  'advantages applying position opportunity work top tier law firm attractive',
#  'hands different embedded processor based development knowledge embedded',
#  'general responsibilities accountabilities responsible managing teams average',
#  'data management ofc roll projects preferably',
#  'qualified ca post qualification big start preferred',
#  'head risk analytics nbfc yrs hiring leading nbfc based mumbai',
#  'managers work industry consulting analytics work within',
#  'job description research investigation companies risk',
#  'professional minimum software development support',
#  'strategic functional role managing high performing teams ranging companys',
#  'extensive project management delivery good big data analytics domain',
#  'designing complex dashboards taking advantage tableau functions including data',
#  'strong interpersonal influencing skills ability collaborate multiple functional experts like',
#  'well versed various data modelling techniques managed team data scientists',
#  'good communication presentation skills good pd ead lgd modeling expected',
#  'designed implemented big data solutions least end end large scale systems high',
#  'creating defining new architectural models explaining complex problems',
#  'candidate qualify checklist written relevant least',
#  'willing work fixed night shift schedule hands p p including external engagement',
#  'candidate gone least one full project lifecycle osc implementation',
#  'core responsibilities develop execute row digital marketing strategy lead',
#  'preparation letter access declarations required customers regulatory',
#  'develop standardized tools methodologies business processes aimed improving operational',
#  'help sales bd good sales capture origination skills selling skills however primary',
#  'functional regression ad hoc testing part every functional',
#  'prioritise problem areas craft intervention strategies either using multi wave multi channel',
#  'interested relocating nagpur candidate mha dha',
#  'candidates good analytical skills mis report maintenance preparing data',
#  'analytics domain human resources additional accenture hr',
#  'engineering team consisting past startup founders iit alumni serial hackathon winners strong',
#  'go getter self motivator min similar capacity',
#  'past delivering individual focused research projects feel comfortable speaking',
#  'desired professionals proven exposure internal sales process e commerce',
#  'proficient understanding code versioning tools git optimization application',
#  'proven proactive leader senior managerial position',
#  'strong leadership mentoring skills minimum team leadership client management',
#  'expert command sql r python applied data science aws',
#  'manage author application lifecycle management documentations including user requirement',
#  'lead setting good example role model behavior consistent words motivates inspires',
#  'team player good stakeholder management certification analytics added',
#  'candidate strong scripting worked data driven key word driven',
#  'cost estimation mandatory total industry oil',
#  'requirement depth knowledge handled sme loans working capital loans',
#  'level tech ecommerce financial companies preferred',
#  'functional finance transformation projects across phases e plan',
#  'candidate localities qualification',
#  'including finance data warehousing projects',
#  'rate analysis costing quantity surveying client billing sub contractor billing qs bar bending',
#  'required qualifications lean six sigmaproblem solvingproject managementminitabms excelms',
#  'minimum database marketing direct marketing crm either highly',
#  'integrating third party libraries apis market data analytics etc',
#  'masters degree reputed institution preferably b architecting business solutions',
#  'technical knowledge proficient key software packages illustrator photoshop data',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'always learning open source technologies practical work w big',
#  'delivering solutions using large datasets data wrangling structured',
#  'building highly scalable business applications involve implementing large',
#  'operation management warehouse',
#  'management elements business stake holders business analytics function',
#  'willingness get hands dirty afraid going real world move across',
#  'excellent communication skills hands operations activities written verbal',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'cloud management portals vrealize automation openstack aws azure',
#  'application development support using distributed technologies',
#  'evaluation development site transfer dossiers documents gap',
#  'creating attractive user friendly content facebook posts twitter instagram',
#  'software development development design skills c net',
#  'mvvm mvc mvp client side implementation extensive usage',
#  'make sure candidate qualify checklist written candidate good',
#  'md minimum degrees minimum total hour medical',
#  'looking professionals statistical modeling advanced',
#  'market research primary market search understand customer need therapy need gap',
#  'performing quantitative analysis preferably technology company expert',
#  'utilize strong analytical ability evaluate end end customer across multiple channels',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'extremely strong program management extremely good communication ppt excel skills',
#  'spend hours day team give spot feedback calls unit managers team leader',
#  'help identify implement new innovations used drive business create unique',
#  'yrs google adwords google analytics certified strong analytical skills',
#  'building distributed data intensive applications',
#  'chartered accountancy degree mba finance premier institute',
#  'chartered accountancy degree mba finance premier institute',
#  'ensuring recruiters submitting matching candidates requirements good turn around time',
#  'handled annual accounts finalization mis business analytics statutory internal',
#  'least building handling large scale systems deep working',
#  'education bba bms mba prior prior strategy good',
#  'good understanding various end user personas information security business',
#  'yrs online marketing digital marketing asset creation vendor management',
#  'min risk reporting functions hedge fund mutual fund industry',
#  'possess analytical skills well organised candidates real estate construction',
#  'demonstrate drive ownership task focus team management led teams projects',
#  'related bs ms degree tier university',
#  'contract change management relationship management good understanding',
#  'developer agile development agile testing environment requires',
#  'hands developing two enterprise product using big data technologies',
#  'relevant consulting needed',
#  'graduate discipline additional post graduation degree preferred continuously research',
#  'client facing capacity strategically led marketing analysis position proven technical',
#  'successful candidate possesses superb business judgment track record successful',
#  'qualification b tech tech pass premier institutes mba',
#  'act positively participate health safety issues site required resident',
#  'good problem structuring skills ability rapidly grasp new concepts industry ability prioritize',
#  'mobile analytics demonstrated deployments enterprise consumer facing mobile',
#  'team management mentor ship good resolving conflicts',
#  'job responsibility person specification strong machine learning r skills',
#  'overall mf yrs looking early joiners minimum hands duration',
#  'ideal candidate need',
#  'minimum three advanced trend analysis ability resource capacity planning',
#  'obtaining comparable degree relevant field logged least management',
#  'overall etl technologies strong sql stored procedures',
#  'able join immediately work would cochin willing work night shifts',
#  'individual digital media advertising operations account management',
#  'good communication skills written oral proficiency ms office functions',
#  'h competencies preferred excellent working knowledge ms office worked complex',
#  'responsibilities understanding business objectives developing models help',
#  'depth knowledge software development lifecycles including agile development testing',
#  'scripting tool like java python candidate bi tools data',
#  'research analysis socio economic data healthcare education etc general management',
#  'good analytical problem solving skills flex time working arrangements work home full part',
#  'manage end end analytics projects including business requirement analysis define scope solution',
#  'writing web crawlers scrapers preferably python java high quality',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'graduate qualifications graduates undergraduate months graduate qualifications',
#  'thorough senior position within real estate sector proven track record',
#  'possesses decent communications skills relevant analytics data',
#  'minimum three prior similar role strong academic background top',
#  'data science analytics past data visualisation',
#  'understanding requirements engineering process business',
#  'maintain strong focus finishing actuarial exams along developing strong subject matter',
#  'prepare financial regulatory reports required laws regulations boards',
#  'product role power sector bank yrs credit assessment tracking',
#  'developing web applications using net mvc jquery using tools like tfs',
#  'working multiple brands digital media industry',
#  'accomplished internet application security professional security',
#  'possess strong knowledge msbi ssas cube design development possess strong',
#  'good written verbal communication skill english strong writing test scenarios',
#  'good problem structuring skills ability rapidly grasp new concepts industry ability prioritize',
#  'deep data platform designing architecting implementation operations standards',
#  'willingness embrace learn new technologies understand business requirement perform',
#  'selling multiple levels buying influences within organizations highly valued',
#  'collaborate product design team deliver top class learning using ui ux best',
#  'credit retail risk banking nbfcs minimum qualification masters',
#  'demonstrated data processing database programming data analytics',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'required qualifications relevant working big data related tech',
#  'proven data management information management equivalent knowledge',
#  'strong problem solving skills ability come creative ideas',
#  'collaborating clients business process enhancements good communication skills verbal',
#  'third party libraries apis agile scrum software development',
#  'work preferably backend auditing payroll transactional processing',
#  'working projects related unified communication mandatory working',
#  'candidates strong mathematics orientation demonstrably good c c skills familiarity',
#  'key role position prepare people reports analyse human resource metrics',
#  'able take onus collections financial institutions within timelines',
#  'worked large data sets excel ms access sql server similar database',
#  'development new customers dealers maximum statutory compliance ensure vehicles',
#  'candidate excellent customer facing capabilities established track record',
#  'hands attitude willingness get details different businesses consulting',
#  'identify cost elements required given solution gather appropriate cost assumptions required',
#  'hands embedded hardware circuit design analog digital mixed signal circuit design',
#  'minimum sales currently minimum rsm level',
#  'working jointly solution architects business consultants senior consultant',
#  'great learning',
#  'designing developing testing custom webmethods application code interfaces',
#  'yrs education background tier',
#  'candidate well versed prequalification tender process statistical analysis',
#  'currently hiring executive financial planning analysis role mumbai',
#  'candidates proven track record developing digital data plans performance reporting',
#  'may required execute new trades instructions various markets provide exceptional client',
#  'using source code management tools e g extensive sort continuous',
#  'focusing customer improve ongoing basis one',
#  'handling complex business requirements bi reporting creating intuitively designed',
#  'supporting utilizing required policies procedures study team members required',
#  'skills ext js job requirements responsibilities strong hands',
#  'deep hands management functions tier tier campus include',
#  'project management transition management role',
#  'capable connecting businesses enable customer consuming actionable insights',
#  'hands writing crisp clear functional requirement documents hands',
#  'opening vc funded series e commerce company based bangalore looking finance',
#  'java creating responsive application total overall',
#  'accenture technology powers clients businesses innovative technologies established emerging',
#  'previous least mobile design full time',
#  'ideal candidate mba finance comparable qualification',
#  'required qualifications relevant working big data related tech',
#  'minimum including minimum search engine analytics',
#  ...]

# %%
list = ' '.join(job_word)  # concatenating the elements in the list 
word_list = list.split()  # spliting the sentence into each word as each element
len(word_list)
# Out:
# 128560

# %%
word_bag =  [] #word_bag of job description
for word in word_list:
    if word not in word_bag:
        word_bag.append(word)
len(word_bag)  #getting the unique words in the job_description word list
# Out:
# 6508

# %%
train['job_description'] = re.sub('[^A-Za-z]+','',str(train['job_description'])) # removing the numbers and other special characters in the job_decription column

# %%
# creating the columns in the train data frame with the words in the word_bag
for word in word_bag:
    train[word] = train['job_description'].apply(lambda b: 1 if word in b else 0)

# %%
train.shape
# Out:
# (19802, 6517)

# %%
# droping the NAN  values in the key_skills column only
skill_temp = train.dropna(subset = ['key_skills'])
# Out:
# (19801, 6517)

# %%
skill_temp = skill_temp['key_skills'].tolist() # selecting the key_skills column and making it into list
len(skill_temp)
# Out:
# ['team skills, communication skills, analytical skills, problem solving...',
#  'ppc, logistics, inventory management, supply chain management, procurement,...',
#  'HR Analytics, Employee Engagement, Training, Succession Planning...',
#  'SQL, Javascript, Automation, Python, Ruby, Analytics, Machine learning...',
#  'accounting, finance, cash flow, financial planning, statutory accounting',
#  'academics, effective communication, teacher training, academic trainer...',
#  'Fraud Analytics, People Management Skills, Team Leading, Problem Solving...',
#  'Accounting, Internal Audit, Auditing, Enterprise Risk Management, Big4...',
#  'esic, hr, bonus, pf, tds, payroll, superannuation, wages, leave...',
#  'accounting standards, finance, auditing, financial planning...',
#  'Test Data, Data Science, Business Analysis, Machine Learning Engineer',
#  'Banking, Model Development, Analytics, People Management Skills...',
#  'Marketing Automation, Sales, Salesforce, Eloqua, Data Analysis...',
#  'Data Science, Machine Learning, R, Big Data, Predictive Analytics, SQL...',
#  'Budgeting, Variance Analysis, Forecasting, Capex',
#  'Spring, Core Java, J2Ee, Hibernate, Javascript, Struts, Python, MySQL...',
#  'Hadoop, HBase, Digital Marketing, Netezza, Unix, SQL Server, Oracle SQL...',
#  'Business Finance, Financial Control, Business Rules, analysis...',
#  'Information Retrieval, Hadoop, Hive, Spark, Mapreduce, SCALA...',
#  'Digital Marketing, Google Adwords, marketing, social media management...',
#  'Business Analyst - Gurgaon, HR',
#  'Business Continuity, Data Privacy, ISMS, Information Security...',
#  'project implementation, client management, sas analytics, analytics, SAS...',
#  'AR, reconciliations, Finance, Accounting, working capital management, SAP',
#  'manual testing, test scripts, performance testing, jmeter, software testing...',
#  'Sales, Equity Research, Investment Research, Investment Banking, DCF...',
#  'amazon, E - commerce, PORTAL HANDLING, Business Analysis...',
#  'finance, mis, business analysis, Excel, Macros',
#  'Analytics, Javascript, SCADA, Outsourcing, Python, Operations...',
#  'Life Insurance, Actuarial, Actuarial Analyst, actuary, Regression Testing...',
#  'Machine Learning, Analytics, Natural Language Processing...',
#  'Javascript, Core Java, Spring Mvc, JSP, J2Ee, MySQL, JDBC, Maven...',
#  'Selenium, Business process, Outsourcing, Analytical, Operations...',
#  'Finance, Insurance, Financial Services, Data Manipulation, Actuarial...',
#  'spark, big data, hadoop',
#  'digital marketing, web marketing, content marketing, google analytics...',
#  'matlab, opencv, image processing, dsp, electrical engineering, intellectual...',
#  'SQL, Oracle, Python, Analytics, Data migration, Postgresql...',
#  'Head - Online Marketing, Online Marketing, acquisition, SEO, analytics, SMS...',
#  'competitive analysis, Civil Engineering, Technical Services',
#  'ITIL, System Analysis, Technical Support, Code Review, Development Testing,...',
#  'cold calling, digital marketing, social media, sales process, smo...',
#  'saltstack, redis, nosql, nginx, docker, linux, machine learning, kubernetes...',
#  'SQL Server, SSIS, SSAS, OLTP, ETL, Analysis Services, Software Development,...',
#  'Analytics, System integration, Asset management, Management consulting...',
#  'SEO, Keyword Research, Link Building, Google Analytics, HTML, Javascript...',
#  'Data Science, Big Data Analytics, Machine Learning, Python, Ansible...',
#  'Static Timing Analysis, RTL Design, Digital Design, IC Design, DFT...',
#  'project planning, technical design, team leading, project management...',
#  'Collections Strategy, Recovery, Collections Process, Risk Analytics...',
#  'XML, Troubleshooting, JSON, Maven, Business process, Outsourcing, GIT...',
#  'market risk, risk management, var, frm, basel, finance, risk analysis...',
#  'Product Consultant, Customer Success, Marketing',
#  'Inventory Management, Warehouse Management, Business Operations...',
#  'Accounting Operations, Accounts Payable, Accounts Receivable...',
#  'Credit Rating, Business Analysis, Financial Analysis, Business Research...',
#  'C#, SQL Server, Design Patterns, C++, Unit Testing, High Frequency Trading,...',
#  'secondary research, business research, primary research, project management...',
#  'part time, freelancing, data entry, present job, work from home...',
#  'Advanced Analytics, Statistical Modeling, Linear Regression, Statistics...',
#  'SAS Data Integration Consultant, SAS Data Integration, SAS BI...',
#  'Auditing, Forecasting, Research Associate, Process improvement...',
#  'ansible, python, aws, Azure, Cloud, Linux',
#  'Spark, Hive, SCALA, Hadoop, Python, Techno Functional, SAS...',
#  'Gl Accounting, SAP FICO, SAP Finance, Copa, Profitability Analysis...',
#  'SQL, Business Intelligence, R, Business Development, Data Analytics...',
#  'SQL, Data Analysis, Text Mining, SAS, R, Statistical Modeling...',
#  'Customer Management, Customer Service, Identity Access Management, Conflict...',
#  'report, team leading, team handling, team management, sas, advance sas, SQL',
#  'Design Development, Performance Testing, Big Data, Core Java, Spark, Kafka,...',
#  'product strategy, conferences, secondary research, technical documentation,...',
#  'recruitment, talent acquisition, mapping, need analysis, capacity planning,...',
#  'molecular biology, biotechnology, toxicology, web technologies...',
#  'analytics, python, project management, modeler, predictive modeling...',
#  'Account Management, Sales, Strategic Planning, Install Base...',
#  'business analysis, ehr, emr, user stories, healthcare, agile, sdlc...',
#  'PeopleSoft Hcm, PeopleSoft Hrms, PeopleSoft Fscm, PeopleSoft Finance...',
#  'banking analytics, team leading, credit cards, business intelligence...',
#  'User Experience, UX, Product Management, Customer Experience, New Product...',
#  'ui development, html5, native, software engineering, React.Js, CSS3...',
#  'SQL Queries, Data Science, Arima, Analytics, Machine Learning...',
#  'project management, pmp, prince2, solutioning, it infrastructure...',
#  'Asset Accounting, Finance, Co, SAP FICO, Profitability Analysis, Ap, Profit...',
#  'Project Management, Product Engineering, Product Development...',
#  'SQL, Excel Powerpoint, R, VBA, MySQL, Python, Data Analysis...',
#  'data entry operation, typing, excel, notepad, freelancing, content writing,...',
#  'Accounting, Book Keeping, Reconciliation',
#  'Verilog, VHDL, RTL Compiler, DFT, Design Engineering, Failure Analysis...',
#  'Invoice processing, Vendor Management, Bank Reconciliation...',
#  'endeca, Atg Commerce, atg e - commerce, Java ATG, ATG implementation',
#  'SQL, Multithreading, OOAD, Coding, Debugging, Investment banking...',
#  'Spark, Hive, Hadoop, SCALA, Java, Big Data, Machine Learning, Python, Rest,...',
#  'new business development, Corporate Strategy, Strategic Planning, Financial...',
#  'Application development, Senior Analyst',
#  'Neural Networks, R, Python, Big Data, Analytics, Data Analysis',
#  'Deep Learning, Machine Learning, Text Mining, Computer Vision, Analytics...',
#  'sales management, business development management, lead generation...',
#  'Presales, Digital Marketing, Digital Strategy, RFP, Sales, Alliances...',
#  'Analytics, Manager - Analytics, Python, consulting, Marketing Analytics...',
#  'Analytics, Business operations, Business process, Data modeling...',
#  'portfolio manager, wealth manager, wealth advisor, investment advisor...',
#  'Marketing Communication, Brand Management, ATL, BTL, Social Media Marketing...',
#  'Oracle, Telecom, Business analysis, TOGAF, Documentation tools...',
#  'pega prpc, java, bpm, application development, business rules...',
#  'SAP BI, UI development, Business process, Outsourcing, Analytical...',
#  'liquidity, treasury, treasury operations, forex operations...',
#  'Global Procurement, Purchase Management, Sourcing, Negotiation...',
#  'Detailing, Communication Skills, Data Migration, Business Analysis...',
#  'project management, project delivery, solution architecting, agile...',
#  'Debugging, Business process, Outsourcing, Operations, PWD, J2Ee, Analytical...',
#  'Spark, Project Management, Big Data, RFPS, Solution Design...',
#  'Ar Calling, ar analyst, accounts receivable, revenue cycle management...',
#  'Data analysis, Outsourcing, Operations, Continuous improvement...',
#  'ERP Functional, Functional Consultancy, Data Processing, Data Management...',
#  'Project Management, Technology Solutions, SCOPE, Solution Architecture...',
#  'Android, SQL, Software Architecture, Software Design, Design Patterns...',
#  'Financial services, Financial analysis, Business analysis, Balance Sheet...',
#  'Enterprise Risk Management, Internal Audit, Sox 404, Auditing...',
#  'Business analysis, Business process, Outsourcing, Business strategy...',
#  'Digital Marketing, eCommerce, sales, brand marketing, marketing...',
#  'High Frequency Trading, Market Making, Quant Trader, Market Maker...',
#  'excel, data analysis, sql, segmentation, data analytics, statistics...',
#  'Business Development, B2B Sales, Corporate Sales, Marketing Planning...',
#  'python, c++, quantitative research, statistical analysis, statistics...',
#  'Advanced Analytics, Statistical Modeling, Linear Regression, Statistics...',
#  'Python, Machine learning, Digital marketing, Forecasting...',
#  'Deep Learning, Natural Language Processing, Machine Learning, NLP, Python...',
#  'Process improvement, Auditing, Analytical, Interpersonal skills, Accounting...',
#  'digital marketing, promotions, segmentation, e - commerce...',
#  'pay per click, google adwords, ppc, campaigns, Search Engine Marketing...',
#  'Business Development, Strategic Planning, Strategy Consulting, B2B...',
#  'finance, financial planning, revenue planning, information analysis...',
#  'Area Credit Manager, Area Credit, LAP, credit, underwriting...',
#  'Predictive Analytics, Data Visualization, Excel, SQL, Data Analytics...',
#  'Analytical, Formulation, Six sigma, Procurement, MS Office, agrochemical...',
#  'Java, Technical Architecture, ETL, Enterprise Architect...',
#  'SAS SQL, Chaid, Logistic Regression, Anova, Excel, R, Time Series...',
#  'Sales Planning, Business Development, Sales Development, Zonal...',
#  'executive search, people management, account management, leadership hiring,...',
#  'Retail Sales, Marketing, Consumer Durables, Sales Planning, Sales Process...',
#  'banking analytics, customer management, customer service orientation...',
#  'Product Manager, Speech Analytics, ML, AI, Deep Learning, NLP...',
#  'DATAANALYST, ANALYST, BACKOFFICE, operations, Data Entry, Backend...',
#  'Presales, Biztalk, Stored procedures, Consulting, SDK, Microsoft Dynamics...',
#  'Data analysis, SQL, Consulting, Data management, SPSS, FMCG, Analytical...',
#  'Android, Kotlin',
#  'Sales Executive Activities, Negotiation Skills, Analytical Instruments...',
#  'safety, environment, occupational health, head of projects, health...',
#  'bpo, customer support, customer service, fresher, freshers, Backend...',
#  'Agile, Scrum Master, Business Analysis, Requirements',
#  'Cluster Analysis, Factor Analysis, SAS, Time Series Analysis, R...',
#  'HR Analytics, Investment Banking, Human Resource Management, Finance...',
#  'Use Cases, Neural Networks, Data Analysis, R, Time Series, Data Mining...',
#  'Hdfs, Mapreduce, Hadoop, Big Data, Access Management, Monitoring Tools...',
#  'HR Executive, Onboarding, Joining Formalities, Exit Formalities',
#  'Logistics, Operations, Warehouse Management, Auditing, Inward, Stock Audit,...',
#  'Marketing Strategy, Sales Management, Sales Forecasting, Territory Growth...',
#  'financial analysis, month end reporting, market research, cost control...',
#  'Project Management, Strategic Planning, Management Consulting...',
#  'Risk Management, SAS SQL, Credit Risk, Wholesale Banking, Risk Analytics...',
#  'Business Development Management, Presentable, Analytical Skills...',
#  'Real Estate',
#  'Design Analysis, Customer Satisfaction, Design Development...',
#  'SEO, Digital Marketing, Google AdWords, Keyword Research, PPC...',
#  'Strategic Planning, Business Consulting, Data Analysis, Media Planning...',
#  'Sales Management, Marketing, IIM, Building Material, Project Management...',
#  'Marketing Automation, Digital Marketing, Email Marketing...',
#  'Project Management, C, IT Strategy, Technology Solutions, Client Engagement...',
#  'Logistic Regression, Linear Regression, SAS, Factor Analysis...',
#  'internal audit, ifc, enterprise risk management, auditing, risk compliance,...',
#  'fund raising, ngo, financial forecasting, donor acquisition...',
#  'back office processing, back office executive, back office assistant...',
#  'Hadoop, Hive, Data Science, Spark, Machine Learning, R, Python, Big Data...',
#  'SAS SQL, Machine Learning, R, Data Extraction, Excel, Python...',
#  'obiee, oracle business intelligence, obi, oracle bi, Obiee Developer...',
#  'C#, Azure, TFS, Project Management, People Management, Go Getter...',
#  'data science, data analytics, statistical analysis, tableau, data modeling,...',
#  'inventory valuation, product costing, cost audit, mis reporting, auditing...',
#  'tender, site, biil, boq, quantity surveying, rate analysis, quantities...',
#  'C++, Algorithm, Solution Design, technical design, software development...',
#  'Financial Accounting, Finance, Accounts Payable, General Ledger, Auditing...',
#  'Impact Analysis, Data Modeling, Business Analysis, Business Solutions...',
#  'online marketing, marketing campaigns, promotional campaigns, web analytics...',
#  'para legal, Paralegal, trademark, patent, intellectual property, ip, IPR...',
#  'Banking, Credit Cards, Personal Loans, MIS Development, Senior Management',
#  'financial analysis, financial planning, financial modelling, pricing...',
#  'Text Mining, R, Machine Learning, SAS, Logistic Regression, SQL...',
#  'SQL, ETL, DW, Bi, PLSQL, Data Migration, Analytics, Business Analysis...',
#  'deep learning, machine learning, text mining, computer vision, analytics...',
#  'SAS, Logistic Regression, Chaid, R, Data Analytics, Anova, Excel...',
#  'Voice Process, call center, bpo, Tele Caller, tele sales, outbound sales...',
#  'Quant Trader, Trader, trading, research, Data Structures, Algorithms...',
#  'Cloud Computing, User Xperience, Artificial Intelligence, AI, ChatBots...',
#  'Ahu, Maintenance, HVAC, Chillers, Technical Support, Energy Audit...',
#  'R, C, Machine Learning, Data Analytics, Python, Deep Learning...',
#  'Supply Chain, Senior Management, Business Intelligence',
#  'adobe analytics, digital marketing, digital analytics, web analytics...',
#  'senior hr, human resource management, workers compensation...',
#  'Linux, Perl, Networking, Python, VMware, Testing tools, Ruby, Analytics...',
#  'Verbal Communication, Communication Skills, Software Quality...',
#  'Deep Learning, Natural Language Processing, Machine Learning, NLP...',
#  'project management, scrum, process consulting, cmmi, software development...',
#  'manual testing, qa, quality analyst, networking, linux',
#  'Access, Excel, Data Analysis, Report Generation, Data Integrity...',
#  '.net, c#, c#.net, quantitative analysis, investment management, analyst...',
#  'Inbound, Outbound, International BPO, Chat Process, Customer Care, customer...',
#  'typing speed, analytical skills, Communication Skills',
#  'Hedge Funds, Finance, Fund Administration, Derivatives, Risk Management...',
#  'Lead Drupal Develoer, Drupal 7, Drupal 8, Technical Lead...',
#  'Senior Analytics Analyst BigData, Spark - Gurgaon, HR',
#  'Customer Marketing, Content Creation, Customer Experience...',
#  'digital marketing, sem, web analytics, marketing campaigns, swot analysis...',
#  'XML, HTML, ePub, CSS / XSLT, Team Leader',
#  'Sales, Strategic Planning, Account Management, Install Base...',
#  'Recruitment, Screening, Interviewing, Hiring, HR, Benefits, Salary...',
#  'search engine optimization analysis, seo writing, seo analyst, seo expert...',
#  'Finance, Financial Management, Budgeting, forecasting, financial reporting,...',
#  'Finance, Financial Reporting, Financial Analysis, Forecasting...',
#  'Big Data Analytics, Consulting, strategy, corporate strategy...',
#  'software development, software design, design patterns, product management,...',
#  'Execution, Analytical Skills, Strategy Analyst',
#  'Project Management, Technical Architecture, SCOPE, Plant Maintenance...',
#  'SQL Database, Tableau, Big Data, SAP BO, Power Bi, PLSQL',
#  'Google AdWords, Marketing Budget, Google Analytics, Display Advertising...',
#  'Test Strategy, Test Reporting, Test Cases, Test Case Execution, Test Lead...',
#  'cyber security, technical support, Network Security, IT Security...',
#  'business strategy, Growth Strategy, Profit Optimization, Operating Model...',
#  'MIS, HTML, XML, VB, Macros, Information security, Analytical, MS SQL...',
#  'management accounting, fpa, management reporting, performance management...',
#  'Recruiter, Recruitment, HR, Human resource, Talent Acquisition',
#  'Social Media Marketing, Lead Generation, Consumer insights...',
#  'Maintenance Activities, General Management, Operations, Preventive...',
#  'Personal Assistance, secretary, executive assistant, personal assistant...',
#  'istqb, automation testing, test planning, cste, sdlc, quality analysis...',
#  'ERP Implementation, Gap Analysis, Business Process, ERP System...',
#  'Python, Data mining, Machine learning, Business process, Outsourcing...',
#  'Production Engineering, Plastic Extrusion, Injection Moulding...',
#  'Accounting, Internal Audit, Auditing, Enterprise Risk Management, Big4...',
#  'finance, financial planning, financial analysis, forecasting, budgeting...',
#  'django, python, javascript, mongodb, nosql, software development, linux...',
#  'BPO, Accounting, Mba Finance, Financial Reporting, Financial Planning...',
#  'Secondary Research, Company Profiling, Market Sizing, Primary...',
#  'ppc, google adwords, facebook, google analytics, linkedin...',
#  'business analysis, business analytics, collections strategy...',
#  'Auditing, Accounting, Payroll Processing, Statutory Compliance...',
#  'business analyst, team leader it, System Engineer, software functionality...',
#  'Fraud Analytics, People Management Skills, Team Leading, Problem Solving...',
#  'google analytics, ppc, marketing management, google adwords, adwords...',
#  'content writing, editing, content editing, content development, editing and...',
#  'Project Management, Program Management, Predictive Analytics...',
#  'Automation Testing, QTP, Test Scripts, Test Engineering...',
#  'Data Science, Analytics, Data Mining, Machine Learning, Factor Analysis...',
#  'Hadoop, Hive, Java, Spark, Cassandra, SQL, SCALA, Redis, Elastic Search...',
#  'SAS, Logistic Regression, Predictive Modeling, Model Validation, Lgd...',
#  'data entry operation, typing, excel, notepad, freelancing, content writing,...',
#  'secondary research, market research, report writing, primary research...',
#  'qc, quality control chemical, qc chemical, quality assurance chemical...',
#  'quantitative research, project management, quantitative analysis...',
#  'valuation, finance, portfolio analysis, credit risk, financial modelling...',
#  'technical support, tech support, technical support executive...',
#  'Legal, Agreements, lease, abstraction, lease admin, lease abstraction...',
#  'SAS, Logistic Regression, Chaid, R, Data Analytics, Anova, Excel...',
#  'Business Development, Sales Lead Generation, Cold Calling, Inside Sales...',
#  'Email Marketing, Lead Generation, Digital Marketing, Business Development...',
#  'Plumbing, Electricals, MEP, Service Delivery, Customer Experience, Category...',
#  'Quality Assurance, Test Engineering, Test Data, Quality Testing, Analytical...',
#  'Product Manager, Product Management, application development, SDLC, feature...',
#  'part time, freelancing, data entry, present job, work from home...',
#  'Delay Analysis, Forensic Planning, Claims, Risk Management, Arbitration...',
#  'SQL, Data Modeling, Data Integration, Supply Chain Planning...',
#  'segmentation, correlation, banking, finance, analytics, clustering, ranking...',
#  'Accounting Operations, Finance, Auditing, Payables...',
#  'IIT, IIM, Digital, Technology, Blockchain, IOT, AI, ML, Entrepreneur, B2B...',
#  'Institutional Equity Reserach Analyst, Equity Research...',
#  'hr generalist, recruitment, agency, hr, exit management, vendor management,...',
#  'Project Management, Client Management, Team Management, Strategy Consulting...',
#  'Digital Marketing, Keyword Research, Online Marketing, Google Analytics...',
#  'Javascript, JSON, Angularjs, HTML, Rest, Java, Spring Framework, GIT, Front...',
#  'JSON, Html5, Java, XML, Software Development, JSP, Aem, Cq5...',
#  'quality control, qc management, quality assurance, haccp...',
#  'AR Calling, Medical Billing, US Healthcare, Senior Ar Associate...',
#  'corporate sales, b2b sales, B2B, business to business, leadgeneration...',
#  'SAS, R, Business Analytics, Predictive Modeling, Linear Regression...',
#  'Financial Accounting, Mba Finance, Financial Management, Consolidation...',
#  'marketing, sales, design engineering, user experience, competitive analysis...',
#  'spss, statistical software, data analysis, sas, alteryx, tableau...',
#  'Machine Learning, Data Analysis, Predictive Analytics, Algorithms, Python...',
#  'Android, Agile Methodology, Product Life Cycle, Performance Analysis...',
#  'part time, freelancing, data entry, present job, work from home...',
#  'Business Process Analysis, business analysis, business research...',
#  'sales support, marketing, presales, business intelligence, market research,...',
#  'Java, NoSQL, MySQL, MongoDB, SCALA, Spark, Hadoop, Python, GIT, Mapreduce',
#  'Marketing, Sales, Competitor Analysis, Market Research, Events, Region...',
#  'SAS, Consulting, Digital marketing, Econometrics, Regression analysis...',
#  'Spark, Mapreduce, Big Data Analytics, SCALA, Data Integration...',
#  'High Frequency Trading, Trading, HFT, Quant, Trading Head, Market Making...',
#  'Javascript, jQuery, WCF, PLSQL, MVC, Web development, Debugging...',
#  'heor, health economics, rwe, real world data, healthcare, pharma, analytics...',
#  'marketing analysis, market research, strategy, social media, data analysis,...',
#  'Accounting, General Ledger, Accounts Receivable, SQL, Data Analytics, Fraud...',
#  'employee engagement, hr, training, learning, Training Analysis...',
#  'Visualization, Analytics, MS SQL, Teradata, OLAP, ETL, Hadoop, Hive, Impala...',
#  'XML, HTML, Web services, Agile, JSON, CSS3, Front end, Version control, GIT...',
#  'part time, freelancing, data entry, present job, work from home...',
#  'competitive analysis, interpersonal communication, rf testing, Radra Expert',
#  'MySQL, NoSQL, Linux System Administration, Rackspace, Cassandra...',
#  'Digital Marketing, SEO, Web Promotion, Web Marketing, Internet Marketing...',
#  'Content Marketing, Advertising, Social Media Marketing, Twitter, Sales...',
#  'Management Accounting, Finance, US GAAP, IFRS, Financial Auditing...',
#  'Financial Analysis, financial planning, budgeting, variance analysis...',
#  'Travel Arrangements, Vendor Management, Office Management, Housekeeping...',
#  'biology, zoology, botany, medical coding, medical coder...',
#  'Pig, Hive, Hadoop, Spark, Big Data, Shell Scripting, Software Engineering',
#  'project management, procure to pay, source to contract, invoicing, accounts...',
#  'field rewards, HR analytics, business partners, HR consulting, Compensation...',
#  'hive, spark, flume, cloudera, sqoop, hdfs, data science, big data, yarn...',
#  'Java, core java, Groovy, Grails',
#  'Business Analysis, E - Tendering, Bidding, Techno commmercial',
#  'Predictive Analytics, Inventory Optimization, Demand Planning, R...',
#  'social media, digital communication, content editor, content writer, nism...',
#  'C#, Biztalk Server, MSMQ, Entity Framework, WCF, Sharepoint Server, C#.Net,...',
#  'IT Infrastructure, Data Center Management, IT Management, IT Operations...',
#  'Project management, PMP, Manager Quality Assurance, Quest, QA...',
#  'BI Analytics',
#  'Agile, Analytics, Business process, Outsourcing, Portfolio management...',
#  'SQL, R, Python, Tableau, analytics, business intelligence, data analysis',
#  'java, android, object oriented design, nfc, threading...',
#  'manufacturing industry, erp navision exposure, cost analysis...',
#  'Product Strategy, Marketing, Sales, B2C, Product Management, B2B...',
#  'salesforce, salesforce.com, force.com, solution architecture...',
#  'Cost Accounting, Finance, Budgeting, Auditing, Product Costing...',
#  'Hadoop, Java, Data Science, Cloudera, Spark, Hive, Impala, Presales...',
#  'real estate, accounts, development, rf, part time, technical support...',
#  'sas sql, r, statistical modeling, risk analytics, statistics...',
#  'Hadoop, Hive, Flume, Oozie, Sqoop, Hdfs, Spark, Pig, HBase, YARN, Avro...',
#  'Business Analyst, Senior Business Analyst, sr business analyst, sr ba',
#  'Data Science, Hadoop, Machine Learning, Spark, Python, Hive, SQL Database...',
#  'google adwords, google analytics, email marketing...',
#  'PMP, Outsourcing, Excel, Operations, Operations management...',
#  'Business Process, Internal Audit, Six Sigma Black Belt',
#  'Java EE, Hibernate, Spring, Javascript, MySQL, Open Source...',
#  'Lgd, Ccar, Risk Modeling, Banking, SAS, Model Development, Analytics, Ead...',
#  'procurement management, logistics, supply chain, market analysis...',
#  'Online Marketing, Excel, PPC, CPA, Analytical Skills, US Inbound sales...',
#  'Acquisition Strategy, Analytics, strategy, clustering, segmentation...',
#  'R, Logistic Regression, SAS, Machine Learning, Segmentation, Python...',
#  'Digital Marketing, Social Media Marketing, Google Analytics, Google AdWords...',
#  'research, market research, business research, company profiling...',
#  'Financial Analysis, Credit Rating, Finance, Financial Sector...',
#  'Javascript, JQuery, Angularjs, Html5, CSS, Node.Js, Adobe Analytics...',
#  'Text Mining, Machine Learning, R, Data Mining, SAS, Logistic Regression...',
#  'supplier quality, qms, internal audit, wires, six sigma',
#  'clinical research, biotechnology, microbiology, zoology, biomedical, bhms...',
#  'Accent, Process Compliance, Quality Standards, Customer Experience',
#  'Banking, Credit Cards, Personal Loans, MIS Development, Senior Management',
#  'credit, credit analyst, credit manager, credit officer, LCV, HCV...',
#  'Shell scripting, Coding, Customer service, Telecommunication...',
#  'On - page Optimization, Off - page Optimization, Google Analytics, SEO...',
#  'financial modelling, business strategy, finance, feasibility studies...',
#  'SAS Visual Analytics Consultant, SAS, SAS Programming...',
#  'ms project, problem solving, compliance issue, operational metrics, jira...',
#  'content writing, technical writing, content management, content designing...',
#  'Shell scripting, Analytics, Business process, Outsourcing, SCALA...',
#  'manager research scientist, machine learning, data - modeling...',
#  'excel',
#  'Quality Assurance Engineering, QA QC Engineer, quality control engineer, qa...',
#  'product management, technical documentation, strategy...',
#  'SQL Server, Software Development, Oracle SQL, Product Testing...',
#  'digital marketing, business development, seo, sem, css, html, web analytics...',
#  'Sales, Business Development Management, Presales, Client Engagement...',
#  'insurance underwriting, underwriting, team leader, back office operations...',
#  'Customer Segmentation, Advanced Excel, SQL, Business Analysis...',
#  'Web Content, Journalism, Content Writing, Editorial, SEO, Content Strategy,...',
#  'SEO, search engine optimization, pay per click, google adwords professional...',
#  'Six Sigma, Green Belt, Process Excellence, Quality Analysis...',
#  'Accounting, Finance, General Ledger, Excel, Word, Payroll Processing...',
#  'mba finance, business intelligence, MCOM',
#  'SAP MM, Analytics, Outsourcing, Downstream, Operations...',
#  'Data Analysis, Data Analyst, Statistics, Analytics, Data Analytics, Problem...',
#  'sas sql, business analysis, analytics, r, data mining, reject inference...',
#  'Performance Appraisal, HR, Training, Self Service, Branch Banking...',
#  'ssrs, ms sql server, ssas, power bi, data warehousing...',
#  'digital marketing, webtrends, web analytics, google analytics, social media...',
#  'Python, Data mining, Machine learning, Outsourcing, Django, Analytical...',
#  'seo, search engine optimization',
#  'Accounting, Internal Audit, Auditing, Risk Advisory...',
#  'SQL Server, Azure, Design Patterns, Data Reporting, Team Management Skills,...',
#  'project management, client engagement, business analysis...',
#  'hr information system, project management, project planning, payroll...',
#  'Gap Analysis, Visio, Excel, Data Mapping, Administration, Team Leading...',
#  'technical, business analysis, requirement gathering, ms office, Requirement...',
#  'Project Management, Spend Management, Supplier Relationship Management, PMO...',
#  'Data Analytics, SQL Database, Data Extraction, Root Cause Analysis, Problem...',
#  'credit underwriting, credit analysis, credit management, risk management...',
#  'smm, seo, search engine optimization, sem, search engine marketing...',
#  'Order management, Risk management, Business process, Outsourcing...',
#  'sta, timing, timing closure, timing analysis, primetime, prime time...',
#  'Design Development, Development Testing, Knowledge Management...',
#  'Assistant Manager - Accounting - Hyderabad, TS',
#  'google adwords, keyword research, google analytics, digital marketing, page...',
#  '.Net, C#, Software Engineering, Unit Testing, Technical Design...',
#  'Product Management, Product Strategy, Product Marketing, User Experience...',
#  'HPLC, GC, Dissolution Tester, UV, Analytical Method Validation...',
#  'Business Analyst, Oracle, Informatica, Project management, Agile, Pega...',
#  'microsoft, Business process, Scheduling, Outsourcing, Operations...',
#  'finance, management reporting, budgeting, financial analysis, forecasting...',
#  'Java, Spring Mvc, Hibernate, J2Ee, Maven, Tomcat, Web Services...',
#  'IT Infrastructure, Data Center Management, IT Management, IT Operations...',
#  'Spring, Hibernate, J2Ee, Core Java, Hadoop, NoSQL, Spark...',
#  'business excellence, black belt, automation, minitab, Robotics...',
#  'QTP, Selenium, JMeter, SQL, Load Runner, Test Scripts, Test Management Tool...',
#  'marketing, competitor analysis, international business, international sales...',
#  'NMR, HPLC, GC, IR, Research, Analytical Techniques, Process Development...',
#  'Node.Js, Javascript, CSS, Html5, Neo4J, Java, GIT, Python, Docker...',
#  'SDLC, Business analysis, Filenet, Investment banking, Test cases...',
#  'Javascript, Python, Bash, Docker, AWS, Azure, Web Technologies...',
#  'Purchase, Excel, Vendor Development, Modeler, MS Office, Cost Reduction...',
#  'Predictive Modeling, Logistic Regression, R, SAS, Predictive Analytics...',
#  'sql, data modeling, etl, data warehousing, data governance...',
#  'SEO, SMM, Affiliate Marketing, SEM, Digital Marketing, Google Analytics...',
#  'asset accounting, internal orders, gl accounting, profit centre, sap fico...',
#  'catastrophe, cat model, catastrophe modelling, catastrophe modeling...',
#  'Data Science, Data Scientist, Machine Learning, R, Python...',
#  'Information Retrieval, Java, Algorithms, Data Science, Spark, SQL...',
#  'Project Management, Project Finance, Financial Modelling, Budgeting...',
#  'python, SAS',
#  'Capital Markets, mathematical models, valuation, R, MATLAB, SPSS, CART...',
#  'big data, data engineer, big data engineer, senior hadoop developer, python...',
#  'Communication, Analytical Skills, Interpersonal Skills, Problem Solving...',
#  'Use Cases, Test Cases, Requirement Gathering, Test Planning, SDLC...',
#  'UML, Automation, Flex, Manager Quality Assurance, LAN, Application support,...',
#  'international bpo, communication skills, quality analysis, sox compliance...',
#  'customer service, bearings, lubricants, vapi, vibration analysis, condition...',
#  'operational tax, tax implications, tax, international tax...',
#  'SQL, SAS Macros, Unix, Continuous Improvement, Business Reporting...',
#  'Java, Android SDK, Android Development, Parsing, Mobile Development, JSON...',
#  'Statistical Modeling, R, Neural Networks, Machine Learning, SAS SQL...',
#  'ux / ui designer, adobe photoshop, illustrator, axure, sketch...',
#  'Product Management, Pricing Strategy, Market Analysis, Product Development,...',
#  'rfp, presales, software services, analytical skills, brd, frd, gap analysis...',
#  'Manager - Process Excellence & Analytics, Process Excellence, Analytics...',
#  'warehouse, inventory, warehouse operations, supply chain...',
#  'Excel, SQL, Data Analysis, Segmentation, SAS, Data Mining, SPSS...',
#  'Excel, MIS, Analytical Skills, Manager MIS, manager mis reporting',
#  'Management Consulting, business consulting, corporate strategy...',
#  'Performance Tuning Analyst, Test Execution, Performance Tuning, Performance...',
#  'private equity, sell side, investment banking, finance, financial modelling...',
#  'medical coding, cpc, cic, coc, ccs, anesthesia, anaesthesia, e&m, Pathology...',
#  'Grunt, Javascript, Karma, Apache Cordova, Couchdb, Spring, Redis, Java...',
#  'Head Hunting, Recruitment, Screening, Leadership Hiring, HR...',
#  'ansible, linux, devops, AWS, Jenkins',
#  'Head - Contact Center Quality, Customer Service delivery, auditing, process...',
#  'secondary research, business research, market sizing, research analysis...',
#  'seo, digital marketing, google analytics, sem, keyword research...',
#  'Investment Banking, Fund Accounting, Reconciliation, Mutual Funds, Cash...',
#  'data reporting, data analytics, ms office, VBA, Macros, PMO',
#  'Direct Sales, Marketing Analytics, Branding, Team Management...',
#  'sas, analytics, statistical analysis, compensation analytics...',
#  'engineering change management, semiconductor manufacturing...',
#  'Production Planning Control, Operations Management, Quality Standards, Team...',
#  'Company Secretary, Legal, Secretarial Activities, Analytical Skills',
#  'Modeller, predictive modeling, market mix modellling, data science, . SQL...',
#  'SAS, Linear Regression, Credit Risk Management, R, Predictive Analytics...',
#  'Oracle, PLSQL, Stored procedures, Data analysis, Business process...',
#  'SQL, Data Analytics, Data Analysis, Excel, Data Mining, Marketing Analytics...',
#  'Basel Iii, Rwa, Business Finance, Market Risk, Credit Risk, Derivatives...',
#  'Hibernate, Spring, Java, Multithreading, SQL, Software Development...',
#  'SCALA, Machine Learning, Java, Python, SQL, R, Pig, Data Mining, Perl...',
#  'Marketing, Lead Generation, Sales, competitor analysis, digital marketing',
#  'Java, J2Ee, Software Development, Software Engineering, Agile Development...',
#  'SEO, Digital Marketing, Search Engine Optimization, Business Development...',
#  'Data Analysis, Predictive Modeling, Data Mining, SAS, Data Analytics...',
#  'Arc Objects, .Net, Java, Map',
#  'Financial Management, Finance, Maintenance, Project Operations...',
#  'Store Management, Store Operations, Promotions, Visual Merchandising...',
#  'Advanced Excel, MIS, Data Analysis, Retail Outlets, MIS Executive...',
#  'Sales, Marketing Campaigns, Promotions, Advertising, Market Research...',
#  'Business Analysis, Business Intelligence, Data Modeling, ERwin...',
#  'Business intelligence, Data analysis, MS Access, MS Office, Data management...',
#  'Pricing Analysis, error rectification, Customer Centric',
#  'garment export, export house, ca, ca qualified...',
#  'SAS, Tableau, Excel, R, Analytics',
#  'financial modelling, dcf, npv, finance, budgeting, management accounting...',
#  'Sales, Equity, Business Analysis, Finance, Settlements...',
#  'Business Management Analyst, Business Management, Financial Forecasting...',
#  'SEO, SEM, Search Engine Marketing, Keyword Research, Web Analytics...',
#  'Advanced Analytics, SAS, R, Data Visualization, Data Mining...',
#  'finance, adhoc testing, scrum, business process, business analysis...',
#  'Java, Bootstrap, JSON, XML, Web Services, OIM, Oracle Identity Manager...',
#  'adl, analytical development, analytical method development...',
#  'customer support, Polymer Testing, enviornmental testing...',
#  'linear regression, machine learning, predictive modeling...',
#  'Javascript, JSON, Angularjs, HTML, Rest, Java, Spring Framework, GIT, Front...',
#  'Informatica, Automation, Eclipse, Information technology, Healthcare...',
#  'Manual Testing, Black Box Testing, Regression Testing, White Box Testing...',
#  'soc analyst',
#  'Java, Angular 5, HTML 5, CSS3, Bootstrap, Karma, Jasmine',
#  'stlc, manual testing, sdlc, qa, jr.qa, writing bug report...',
#  'Finance, Macros, Advanced Excel, VBA, Management Reporting, MIS Reporting...',
#  'big data, solution architecture, program management, scp, iot, block chain,...',
#  'Analytics, Predictive modeling, Statistical Analyst, Time series analysis...',
#  'mystery shopping, market research, Freelancer, work from home, part time...',
#  'Customer Operations, Sourcing, Supply Chain, Inventory Planning...',
#  'hr analytics, execution, project management, data management, fixed income',
#  'tableau, Data Analytics, Data Analysis',
#  'SAP, Workflow, Access management, Business process, Outsourcing, Operations...',
#  '" ; Deep Learning" ; , Neural Networks, Machine Learning',
#  'recruitment, it hiring, hr, talent acquisition, executive search...',
#  'MIS, MIS Reporting, MIS Preparation, MIS Updation, MIS Coordinator...',
#  'estimation, costing, budgeting, qs, quantity surveyor, quantity surveying...',
#  'C++, Python, Java, Algorithms, Neural Networks, Machine Learning, SCALA...',
#  'marketing, advertising, campaigns, activation, b2b, keyword research, ppc...',
#  'Sales, Business Development, Marketing, Prospecting, Client Relationship...',
#  'Technical Support Analyst - Desktop Support - Hyderabad, TS',
#  'QC, Analytical Testing, analytical qa',
#  'business development management, b2b sales, marketing initiatives...',
#  'procurement, auditing, accounting, finance, resource planning, process re -...',
#  'SQL Queries, Informatica, Cognos, Data Integration, Webfocus, Microstrategy...',
#  'Cost Accounting, Finance, Financial Accounting, Inventory Accounting...',
#  'Search Engine Marketing, SEM, PPC, Google Analytics, Webtrends, Omniture...',
#  'company research, market research, finance, competitive analysis, financial...',
#  'process definition, cmmi, iso 9001, quality assurance, quality management...',
#  'ABAP, Business process, Outsourcing, Operations, Export import...',
#  'oracle financials, oracle fusion, user administration, revenue management...',
#  'Data Analytics, SQL, Statistics, R, Econometrics, Data Mining...',
#  'asp.net, c#.net, mvc, sql server, jquery, software development',
#  'Design Patterns, SOAP, Multithreading, XML, Core Java, Agile Development...',
#  'international call center, technical support, social media...',
#  'SEO Analysis, Online Marketing, Internet Marketing, Link Building...',
#  'SQL Server, Data Profiling, Data Governance, ETL Tool, Data Quality...',
#  'Plant Operations, Plant Management, Record Keeping, Report Generation, Soft...',
#  'Credit Risk Analytics, Credit Risk, Credit, business architecture...',
#  'Test Cases, Test Analysis, Performance Testing, Test Analyst, .NET, C#',
#  'Corporate Sales, Sales, business development',
#  'Marketing, Sales, Product Analysis, People Management Skills...',
#  'construction finance, housing finance, market intelligence, data analysis...',
#  'sitecatalyst, web trends, web analytics, web analyst, ensighten, tealium...',
#  'JIRA, Business process, Outsourcing, Resource management, Agile methodology...',
#  'Manual Testing, Selenium, API Testing, Appium, Mobile Testing, Testng, Test...',
#  'iot, telecom, smart cities, Project Management, Project Coordination...',
#  'Oracle SQL, Unix, Hana, SAP Basis, Database, Windows OS...',
#  'Quality Assurance Analyst, Unix, Windows, Flex, LAN, Application support...',
#  'digital analytics',
#  'Application Lead, REST, JSON, XML, HTTP, Power BI, Kibana, Grafana, Python,...',
#  'SALES FORCE, SAP BI, MS OFFICEMS EXCEL, ANALYTICAL SKILLS...',
#  'Operations Management, Lean Six Sigma, Operational Excellence...',
#  'Java, Rabbitmq, J2Ee, Redis, Spring Framework, Cloud Foundry, JUnit, SCALA,...',
#  'testing, test engineer, manual testing, qa, test case, automation testing...',
#  'SEO, Digital Marketing, Google AdWords, SEM, Affiliate Marketing, PPC...',
#  'SAS DI, Base SAS, Analytics, Campaign Management, Marketing...',
#  'SQL, VB, WCF, Automation, Application support, Problem management...',
#  'market research, healthcare, life sciences, pharma, pharmaceutical, medical...',
#  'Compensation, Benefits',
#  'Digital Marketing, Social Media Marketing, Online Marketing...',
#  'SAS, UNIX, SAS Enterprise Guide, Big Data, Hadoop, analytics',
#  'project management, pmp, prince2, solutioning, it infrastructure...',
#  'SEO, PPC, Web Development, Web Technologies, SEM, search engine marketing...',
#  'Onesource, Business Research, Competitive Intelligence, Bloomberg, Research...',
#  'SQL Scripting, Performance Tuning, Database Design, Views, Consulting...',
#  'excel, data analytics, data collection, data management, supply chain...',
#  'Marketing Support, Sales, Brand Strategy, Marketing Analytics...',
#  'Credit Analysis, Credit Risk, Portfolio Management, Healthcare, IT',
#  '.Net Developer',
#  'Digital Marketing, Social Media Marketing, SEO, Google AdWords...',
#  'training, career planning, maintenance activities, performance management...',
#  'Sales, Research Analysis, Equity Research, Investment Banking, Valuation...',
#  'Analyst - Financial Planning, Financial Services General',
#  'Ccar, Risk Management, Forecasting, Model Development, Consumer Finance...',
#  'ERP, Business objects, Workflow, Business process, Outsourcing, Analytical,...',
#  'Deep Learning, Node.Js, Javascript, NoSQL, Elastic Search, JSON, Artificial...',
#  'Automation, System software, Operations, Root cause analysis...',
#  'Data Modeling, Big Data, SAAS, Analytical Engines, Campaign Management',
#  'credit, credit documentation, credit appraisal, credit analyst...',
#  'data entry operation, data entry operator, dataentry, customer service...',
#  'Project management, Analytics, Service management, Outsourcing, Analytical,...',
#  'SQL, Predictive Modeling, R, SAS, Analytics, Statistics, Tableau...',
#  'project management, data analysis, market research, analytics...',
#  'Process Engineering, Network Design, Modeling',
#  'SQL, Data Warehousing, Business Intelligence, Data Integration, ETL...',
#  'SAS, Data management, Oracle, SPSS, Cognos, Business objects...',
#  'Business Analysis, Use Cases, Business Analytics, Business Intelligence...',
#  'dcf, lbo, pitch books, financial analysis, project finance...',
#  'Physical Design, Timing Closure, Timing Analysis, Signal Integrity...',
#  'SEO Writing, Google Webmaster Tools, Link Building, Off - page Optimization...',
#  'Java, MVC, MySQL, .Net, Python, Scalability, SQL Server, Web Technologies...',
#  'learning development consultant, Induction, training',
#  'identity access management, auditing, iam, it infrastructure...',
#  'SQL, Informatica, Datastage, Python, Production support...',
#  'Pega, Consulting, Information technology, Recruitment, BPO...',
#  'MS Dynamics CRM, Office Skills, Technical Support, Production Support...',
#  'health insurance, regulatory compliance, strong analytical skills, Legality...',
#  'client servicing, customer support, customer care, international bpo, voice...',
#  'Strategy Assistant, Executive Assistant, Corporate Strategy, marketing...',
#  'Windows, Client management, Oracle, Unix, Scheduling, Incident management...',
#  'Interface Builder, Objective C, IOS, Swift, Apple, Software Development...',
#  'Service delivery, SQL, SAS, Consulting, Assurance, Continuous improvement...',
#  'project management, project execution, project governance, waterfall, agile...',
#  'hive, hadoop, flume, sqoop, oozie, sql server, impala, ssrs, solr, java...',
#  'Finance, Banking, Financial Modelling, Project Funding, Fund Raising...',
#  'sales strategy, business analysis, sales force optimization...',
#  'Query Designer, Bex Analyzer, SAP BI, SAP BW, SAP BO, WebI...',
#  'Data Analyst, PV Case Processing, Pharmacovigilance, Data Analysis',
#  'nlp, text mining, data science, text analytics, python, r, Claims Analytics...',
#  'adobe analytics, strategy, web analytics, data integration...',
#  'Research Analysis, Executive Assistant, Data Analytics',
#  'Captivate, Photoshop, Flash, ILT, Illustrator, Instructional Design, WBT...',
#  'Analytical Skills, Machine Learning, Optimization, Problem Solving',
#  'unit testing, test cases, javascript, jquery, CSS, Bootstrap, PHP, JSP',
#  'Financial Accounting, Finance, Budgeting, Taxation, Financial Reporting...',
#  'Analytics, Predictive Modeling, SCM Analytics...',
#  'Google Analytics, Ad Tags, Google Tag Manager, Doubleclick for Publishers...',
#  'adobe analytics, web analytics, digital analytics, digital marketing...',
#  'sales promotion, marketing initiatives, primary sales, sales management...',
#  'SEO, Digital Marketing, SEM, SMM, Social Media Marketing...',
#  'Model Validation, Monthly Reports, Cash Equities',
#  'part time, freelancing, data entry, present job, work from home...',
#  'Digital Marketing, SEO, Google AdWords, SEM, Social Media Marketing...',
#  'C, C++, VC++, Linux, OS, Design Patterns, Team Leading, Capital Market...',
#  'Fund Accounting, Finance, US GAAP, IFRS, Auditing, Fixed Income Derivatives...',
#  'seo analysis, digital marketing, internet marketing, online marketing...',
#  'data analytics, data reporting, data cleansing, troubleshooting skills...',
#  'visualforce, sfdc, triggers, salesforce, Salesforce Developer...',
#  'Market Research, Business Research, Market Analysis, Strategy Consulting...',
#  'Qualitative Research Manager, Market Research, Marketing...',
#  'Corporate Business Development, Marketing, Sales Strategy, Franchising...',
#  'SEO, SEM, Display Advertising, Digital Marketing, Google Analytics...',
#  'Project Management, Healthcare Analytics, SCOPE, Consulting, Project Design',
#  'Product Design, Software Development Life Cycle, Software Solutions...',
#  'quality evaluator, international bpo, domestic bpo, quality analyst, qc, qa...',
#  'Product Marketing, Machine Learning, Python, R, Marketing Operations...',
#  'SAS, Logistic Regression, Predictive Modeling, Model Validation, Lgd...',
#  'Marketing, Sales Analysis, Operations Management, Branding...',
#  'Webtrends, Adobe Analytics, Media Marketing, Web Analytics...',
#  'Fraud Analytics, People Management Skills, Team Leading, Problem Solving...',
#  'credit control, Treasury, CA, Chartered Accountant, Audit',
#  'Business process, Gap analysis, Integration services, UAT',
#  'Merchant Services, Business Analyst, HTML, PHP, APIs, workflow design',
#  'Analytics, SAS, people management, P&C analytics, Analytics Head',
#  'banking, analytics, team leading, problem solving, retail business, sas...',
#  'Text Mining, Hive, NoSQL, Python, R, SQL, Data Analysis, Machine Learning...',
#  'Corporate Sales, General Insurance, Strategy Development, Analytical Skills...',
#  '" ; Jquery" ; ...',
#  'Project Management, Program Management, Predictive Analytics...',
#  'Analytics, fixed income, Bloomberg, derivatives, quantitative models...',
#  'SAP FICO Consultant, Cost Element Accounting, Cost Center Accounting, Copa,...',
#  'user stories, scope, visio, project management, business analysis...',
#  'Accounting, Finance Control, MIS, MS Office, Statutory Reporting...',
#  'Key Accounts, Relationship Management, Go Getter, Supply Chain...',
#  'HTML, XML, Javascript, Web Services, MVC, Java, SOAP, MS SQL Server, UDDI...',
#  'SAS, Predictive Modeling, Segmentation, Model Development, Scorecard...',
#  'Technical Sales, Solution Architecture, Technical Architecture, Java...',
#  'media buying, digital marketing, sales, branding, media planning...',
#  'Deep Learning, Data Science, Predictive Analytics, SQL, Data Visualization,...',
#  'Project Management, PMI, Program Management, Sales, SCOPE...',
#  'Content Marketing, Email Marketing, Digital Marketing, SEO...',
#  'Analytics, Service management, Outsourcing, Operations, orchestration...',
#  'Text Mining, R, Time Series Analysis, Machine Learning, SAS...',
#  'it recruitment, hr, executive search, hiring, talent acquisition...',
# ...
#  'Strategic Analytics, Analytics, Customer Management, banking portfolio...',
#  'international call center, international bpo, domestic ticketing...',
#  'algorithms, data structures, Microsoft Azure, AWS, Google Cloud Rackspace...',
#  'medical coding, medical coder, zoology, microbiology, biotechnology...',
#  'Cold Calling, Inside Sales, Marketing Executive, Pre Sales Executive...',
#  'Management Accounting, Commercial Management, MIS, Procurement...',
#  'MongoDB, Java, MySQL, NoSQL, Elastic Search, Ansible, Cassandra, Docker...',
#  'project finance, financial modelling, project appraisal, financial analysis...',
#  'secretarial activities, secretarial skills, typing, communication skills...',
#  'Marketing Campaigns, Promotions, Events, Marketing Management...',
#  'sql, TSQL, T SQL, triggers, Stored Procedures, cursor, MSBI, SSIS, SSRS...',
#  'Channel Sales, Salesforce, Primary, Strategy, Customer Experience, Business...',
#  'Rural Finance, Financial Analysis, Credit Underwriting, Credit Risk...',
#  'r, big data analytics, predictive modeling, neural networks, use cases...',
#  'Commercial, Budgeting, MIS, Modern Trade, customer reconciliation, Finance,...',
#  'Adobe Analytics aka Omniture, SiteCatalyst, " ; site Catalyst" ; ...',
#  'Performance Engineering, Networking Protocols, Bash Scripting, Openstack...',
#  'Networking, SQL, Investment banking, Process improvement, CFD...',
#  'Software Development, Software Engineering, Java, Software Design, Software...',
#  'Cyber Security',
#  'sales, sas, r, hr analytics, human capital, machine learning...',
#  'Predictive Analytics, Data Science, R, Neural Networks, Machine Learning...',
#  'Design, Development',
#  'BPO, KPO, MNC, Medical Billing, Process Associate, us healthcare...',
#  'PHP, Magento, Web Content, Blogs, Html5, Articles, UX, User Experience...',
#  'Java / J2EE, Quality Management System, Quality Management, Java, J2EE...',
#  '" ; data analysis" advance analytics, logistics, regression...',
#  'offline, online, part time, home base, work from home, freelancer...',
#  'offline, online, part time, home base, work from home, freelancer...',
#  'Java, J2EE, Azure, Dockers, Kubernetes, Chef, J2EE servlet, SQL, PL / SQL...',
#  'SEO Analysis, SMO, Social Media Optimization, Search Engine Optimization...',
#  'Accounting, Mba Finance, Financial Analysis, Financial Reporting, Financial...',
#  'SQL javascript, excel, vlookup, countif, data validation, vb, vba, triggers',
#  'networking, disaster recovery, investment management, change control...',
#  'channel sales, event marketing, distribution network, direct sales, channel...',
#  'C, AWS, Cloud Computing, Scalability, Azure, Automation Testing...',
#  'r, excel, sas, analytics, business consulting, business consultant...',
#  'Front- End, UI, Angular JS, HTML5, CSS, JavaScript, CSS3, jQuery, React JS,...',
#  'Computer Vision, Machine Learning, Distributed computing, algorithms, OCR...',
#  'Credit Analysis, Corporate Credit, Credit Appraisal, Credit Rating, Finance...',
#  'Project planning, PSD, Business process, Outsourcing, Dialog programming...',
#  'data analytics, data modeling, data mining, data extraction, senior analyst...',
#  'hr operations, onboarding, induction, compensation, payroll management...',
#  'High Frequency Trading, Trading, trading strategies, Design, testing, trade...',
#  'accounting, financial services, UK payroll, uk payroll processing...',
#  'Content Writing, SEO Analysis, SEO Writing, SEM Analyst, Digital Marketing,...',
#  'salesforce, user acceptance testing, business analysis, Business Analyst',
#  'crm, data quality, data reporting, saas, data analytics, business analytics...',
#  'Research, LCMS, Bioanalytical, Method Development',
#  'Systems Analyst, Systems Analysis, UI / UX, Siebel',
#  'Artificial Intelligence, Machine Learning, Java, Supply Chain Planning, Sap...',
#  'Forecasting, Business Management, data analytics, reporting, analytics',
#  'Jenkins, Continuous Integration, Problem Solving, Quality Tools, Root Cause...',
#  'Cost Accounting, Standard Costing, Budgeting, Finance, Inventory Valuation,...',
#  'ssrs, ssas, msbi, dw',
#  'J2Ee, Java, Project Management, Java / J2EE developmen, Java / J2EE Project...',
#  'Project Estimation, project proposal, Tableau, Python, R, Bi...',
#  'BPO, Customer service, Recruitment, Consulting, Financial services, VPN...',
#  'HR, Head - HR, HR Operations, Payroll, Payroll ops, Budgeting, Compensation...',
#  'SEO Analysis, Google Webmaster Tools, Off - page Optimization...',
#  'Postgresql, MySQL, Javascript, Excel, XML, SQL, Data Mining, Data Analysis,...',
#  'taxation, gst, indirect taxation',
#  'strategy consulting, analytical skills, management consulting...',
#  'Analytics, Project planning, Business process, Data quality, Outsourcing...',
#  'Ad Sales, Digital Sales, Media Sales, Online Advertising, Ad Operations...',
#  'marketing initiatives, market intelligence, strategic business planning...',
#  'finance, auditing, hr, taxation, compensation, leave, payroll software...',
#  'JSON, Microsoft Azure, Java, Product Marketing, XML, Web Services...',
#  'Accounting, Project Finance, Financial Analysis, Financial Planning...',
#  'computer vision, deep learning, c++, image processing, algorithms...',
#  'SQL Queries, Data Science, Arima, Analytics, Machine Learning...',
#  'business analysis, servicenow',
#  'Production Support, Application Support, Technical Support, Teradata...',
#  'Use Cases, Sales Process, Business Development, Business Analysis...',
#  'uat, business analysis, project documentation, Business Analyst...',
#  'R, Machine Learning, Customer Analytics, Python, Data Analytics...',
#  'Biw Design, VPM, CATIA, Dmu, DFMEA, NX, Cae, Exterior, FE Analysis, Seating',
#  'Text Mining, Machine Learning, R, Predictive Modeling, SAS...',
#  'SAS, Coding, Data mining, Business intelligence, Analytical...',
#  'Product Sales, Bd, Presales, cisco, sales, consultant, engineer, VPN...',
#  'Financial Reporting, Month End Reporting, Direct Tax, Budgeting...',
#  'Excel, SQL, Data Analysis, Segmentation, SAS, Data Mining, SPSS...',
#  'Primavera P6, Primavera Unifier, Primavera Analytics, Primavera tester...',
#  'Pharmacovigilance, MedDRA, Medical Coding, Bhms, Bams, PV, Drug Safety...',
#  'financial planning, financial analysis, financial reporting',
#  'r, neural networks, sas sql, machine learning, advanced analytics, python...',
#  'Oscp, Vulnerability Assessment, Penetration Testing, Vapt, Networking...',
#  'Machine Learning, R, Hadoop, Data Mining, Statistical Modeling...',
#  'Javascript, Django, CSS, JQuery, HTML, Pyramid, Python, MongoDB, NoSQL...',
#  'business analysis, visio, wireframing, excel, ms project, ms office...',
#  'Cloud Computing, Spark, Python, Azure, Big Data Analytics, Open Source, Web...',
#  'operations, development, seo, sem, co, web development, analytics, php',
#  'Sales, CRM, Business Applications, ERP, software sales',
#  'Web Analytics, Web Technologies, Google Analytics, DTM...',
#  'data analytics, data mining, data analysis, analytics, statistical analysis...',
#  'Deep Learning, NLP, Spark, Information Retrieval, Java, Python...',
#  'matlab, c++, modeler, programming, technical support...',
#  'Gl Accounting, Accounts Payable, General Ledger, Accounts Receivable...',
#  'Marketing, Sales, Content Designing, Advanced Excel, Advanced Analytics...',
#  'Digital Marketing, SEO, Sales, Web Analytics, Customer Experience, IIM...',
#  'Erp Consulting, Chartered Accountant, ca, ca inter, ERP Implementation',
#  'R, SQL, Big Data Analytics, Logistics, Predictive Analytics...',
#  'rfi, rfp, business development, market research, bidding, consulting...',
#  'cyber security, cyber forensics, hmm, isoc, edr, crowdstrike, carbon black,...',
#  'Agile, User Acceptance Testing, Business Analysis, Business Operations...',
#  'Information security, SOC, Outsourcing, SIEM, infrastructure security...',
#  'Process Design, Lean Manufacturing, Plant Layout, QC Tools...',
#  'project management, should costing, should cost, should be costing...',
#  'QA Analysis, Functional Testing, System Testing, Automation Testing...',
#  'Quality Assurance, Inprocess Quality, QA, Validation, Batch Manufacturing',
#  'Pain Management, AR Follow - up, AR CALLING, HEALTHCARE, Medical Billing...',
#  'BPO, KPO, US Shift, Excel, MIS Preparation, MIS, MIS Reporting, MIS Officer...',
#  'secondary research, web research, online research, content generation, data...',
#  'Full Stack Engineer, Full Stack, Elastic Search, Solr, SQL, Oracle, No SQL,...',
#  'customer analytics, iim, tableau, data analytics, advanced analytics...',
#  'Application Support, production support, .Net, MSBI',
#  'Accounting Standards, IFRS, Ca, IAS, Inter, IPCC, MS Office...',
#  'Project Accounting, Finance, Taxation, Fixed Assets...',
#  'rwa, financial products, balance sheet, financial management, credit risk...',
#  'Business Development, product configuration, Product Positioning...',
#  'Sales, Business Planning, Project Management, Strategy...',
#  'Troubleshooting, Data analysis, Manager Quality Assurance, Data processing,...',
#  'semi voice process, semi voice, non voice, non voice process, fresher...',
#  'Quality Audit, Talent Development, Service Quality, Six Sigma Quality...',
#  'Outbound, Inbound, Marketing, Advertising, Post Sales, Communication Skills...',
#  'ABAP, XSLT, Webmethods, NWDI, UDF, Performance monitoring, Business Analyst...',
#  'Lgd, SQL, FRM, Client Presentations, Analytics, Ead, R, STATA...',
#  'Statistical Software, Customer Service Management, Operations, Excel, SAS...',
#  'SAS, Chaid, Factor Analysis, R, Predictive Analytics, Text Mining, Excel...',
#  'Automation Testing, QTP, Selenium, Test Scripts, Software Testing...',
#  'revenue maximization, auditing, business development, data analytics...',
#  'R, Product Sales, Data Analysis, Data Analytics, Marketing Campaigns, SQL...',
#  'Db2, Cobol, JCL, Configuration management, Analytics, Monitoring...',
#  'msc, msc freshers, organic chemistry, msc 2016 pass, msc 2017 pass...',
#  'panda, nlp, machine learning, python, data analysis, it consulting...',
#  'Software Development, software engineer, software developer...',
#  'Project Management, Solution Design, Process Consulting...',
#  'Strategic Marketing Planning, Business Development, Sales...',
#  'Reporting, Metrics, social media listening, ESM, Google Analytics, Facebook...',
#  'Marketing, PR, Social Media, Campaigns, Content Strategy, Digital Content...',
#  'iOS Developer, iOS, Objective C, SWIFT, Xcode, information architecture...',
#  'HR, Grievance Handling, Hrbp, Employee Relations, Onboarding...',
#  'RFI, Presales, RFP, RFQ, Sales, Project Management, Proposal Preparation...',
#  'accounting, bank reconciliation, debtors, tds, tally software, book keeping...',
#  'HR Strategy, Employee Engagement, Talent Management, Talent Acquisition, HR...',
#  'Campaign Analytics, Data Analysis, SAS Programming, Data Management...',
#  'MES Apriso, Hydra, Oracle, SQL, Dot Net',
#  'Machine Learning, Speech Scientist, Artificial Intelligence...',
#  'Process Training, Customer Operations, Soft Skills Trainer...',
#  'valuation, finance, portfolio analysis, credit risk, financial modelling...',
#  'Gap Analysis, SAP Consulting, SCM, Logistics, Business Analysis...',
#  'Data Analysis, Tableau, tableau 10',
#  'Financial Controller, Accounting, Finance, Business, head finance, CFO...',
#  'management reporting, it asset management, power bi, data integrity, strong...',
#  'Html5, User Interface Designing, Javascript, JQuery, Web Designing...',
#  'Finance, Accounting, f&a, Budgeting, mis, mis reporting, variance analysis,...',
#  'business analysis, System Analyst, Business Analyst...',
#  'Base SAS, SAS Programming, Development Testing, Requirement Analysis...',
#  'sql, unix shell scripting, spark, nosql, big data, performance tuning...',
#  'deep learning, machine learning, natural language processing...',
#  'business analysis, functional consultant, sdd, sdlc life cycle...',
#  'mba finance, performance improvement, report preparation, People Management...',
#  'Marketing, Competitive Analysis, Market Research, Product Management...',
#  'sales forecasting, sales analysis, sales coordination, sales co - ordinator...',
#  'Laravel, Javascript, CSS, Html5, JSON, Android...',
#  'HTML, Web Tools, Web Technologies, SEO Analysis, SEO Executive...',
#  'Product Strategy, Product Management, Analytics, Machine Learning...',
#  'Sap Accounting, Accounts Payable, Invoice Processing, Auditing, Gst...',
#  'Java, J2Ee, Web Services, Portal, Web Technologies, Software Engineering...',
#  'trade finance, risk mitigation, contract administration...',
#  'Business Analysis, Real Estate',
#  'Six sigma, Project management, Financial services, Data management, PMP...',
#  'Business Development, Channel Development, Consumer Goods...',
#  'Oracle SQL, SQL Database, Business Analysis, Business Analytics, .net, FRD....',
#  'SEO Analysis, SMO, Blogs, Twitter, Youtube, Content Writing...',
#  'business analysis, real estate, property acquisition, land acquisition...',
#  'spring, java, hibernate, j2ee, scalability, solution design...',
#  'Android Studio, Java, DAO, XML, GIT, Continuous Integration...',
#  'Cold Calling, Business Development, Outbound Calling, outbound sales...',
#  'search engine marketing, social media marketing, online marketing...',
#  'adobe analytics, javascript, webtrends, jquery, seo, google analytics, aem,...',
#  'Investment Banking, Technical Analysis, Reporting Tools, Web Technologies...',
#  'academic research, creative writing, mba fresher, mba marketing...',
#  'sap bw, sap bi, sap hana, sap ecc, power bi, SAP, SAP Business Intelligence...',
#  'Networking, Customer Support, Chat, Hardware, Remote Support, Email Support...',
#  'Machine Learning, Python, C++, Java, R, MATLAB, Perl, Predictive Modeling...',
#  'Accounting, Accounts Payable, Payment Processing, Finance...',
#  'Health Insurance, Health Claims, TPA, Claims Management, Medical...',
#  'SIP, H323, CUCM, MGCP, Voice Gateways, Cisco IP Telephony, Networking...',
#  'Arcsight, SOC, Splunk, Network Analysis, Application Software...',
#  'supply chain management, scm management, Working Capital',
#  'Information Retrieval, Java, Algorithms, Data Science, Spark, SQL...',
#  'Software Development, Product Development, Software Engineering...',
#  'security analysis, security operations, siem solutions, vulnerability tools...',
#  'Android Developer, Java, JSON, XML, Android, Cloud APIs, OOPs, Core Java...',
#  'project planning, gnatt chart, sdlc, analytical skills, sql server database...',
#  'Quality Analyst, qa, Voice, Call Monitoring',
#  'SQL, Windows, Agile, Selenium, Healthcare, JIRA, Test management...',
#  'spark, sql, big data, hadoop developer, hadoop',
#  'Project Management, Business Transformation, Business Analysis...',
#  'Multivariate Analysis, Time Series Analysis, Cluster Analysis, Modeler...',
#  'Predictive Analytics, SQL, R, SAS, Business Analytics, Marketing Programs...',
#  'cpg, cpg analytics, cpg data analytics, cpg data mining, cpg data analysis,...',
#  'SEO, Digital Marketing, Social Media Optimization...',
#  'java, html, programming, coding, category, catalog, taxonomy...',
#  'Business process, Outsourcing, Analytical, Operations, Web services...',
#  'Hive, Hadoop, Oozie, Spark, SQL Server, Java, Financial Accounting, SCALA...',
#  'US Accounting, Quick Books, Taxation, Balance Sheet, Auditing, Profit, Loss...',
#  'Advanced Analytics, SQL, Machine Learning, Data Manipulation...',
#  'Lookup, Advanced Excel, Pivot Table, VLOOKUP, MIS Reporting, MS Office...',
#  'Oracle, MS SQL Server, Modeler, Big Data, Data Modeling, Database Design...',
#  'Data Structures, Algorithms, C++, Analytics, Programming, Time Series...',
#  'Business Finance, Accounting, Budgeting, Taxation...',
#  'Project Development, Gap Analysis, Technical Training, Project Management...',
#  'sem, search engine marketing, PPC, CPM, CPC, CPL, CPA',
#  'ESS, Gap Analysis, MSS, SAP HCM, UAT, User Acceptance Testing...',
#  'Hr Reporting, Data Analytics, Data Analysis, Hiring, Compensation...',
#  'MySQL, Javascript, Web Development, Sitecatalyst, Web Analytics, XML, Java,...',
#  ...]

# %%
wordlist= [] 
for i in skill_temp:
    temp = normalize_document(i) # removing the white space,special characters and numbers using user defined function
    wordlist.append(temp)
len(wordlist)
# Out:
# ['team skills communication skills analytical skills problem solving',
#  'ppc logistics inventory management supply chain management procurement',
#  'hr analytics employee engagement training succession planning',
#  'sql javascript automation python ruby analytics machine learning',
#  'accounting finance cash flow financial planning statutory accounting',
#  'academics effective communication teacher training academic trainer',
#  'fraud analytics people management skills team leading problem solving',
#  'accounting internal audit auditing enterprise risk management big',
#  'esic hr bonus pf tds payroll superannuation wages leave',
#  'accounting standards finance auditing financial planning',
#  'test data data science business analysis machine learning engineer',
#  'banking model development analytics people management skills',
#  'marketing automation sales salesforce eloqua data analysis',
#  'data science machine learning r big data predictive analytics sql',
#  'budgeting variance analysis forecasting capex',
#  'spring core java j ee hibernate javascript struts python mysql',
#  'hadoop hbase digital marketing netezza unix sql server oracle sql',
#  'business finance financial control business rules analysis',
#  'information retrieval hadoop hive spark mapreduce scala',
#  'digital marketing google adwords marketing social media management',
#  'business analyst gurgaon hr',
#  'business continuity data privacy isms information security',
#  'project implementation client management sas analytics analytics sas',
#  'ar reconciliations finance accounting working capital management sap',
#  'manual testing test scripts performance testing jmeter software testing',
#  'sales equity research investment research investment banking dcf',
#  'amazon e commerce portal handling business analysis',
#  'finance mis business analysis excel macros',
#  'analytics javascript scada outsourcing python operations',
#  'life insurance actuarial actuarial analyst actuary regression testing',
#  'machine learning analytics natural language processing',
#  'javascript core java spring mvc jsp j ee mysql jdbc maven',
#  'selenium business process outsourcing analytical operations',
#  'finance insurance financial services data manipulation actuarial',
#  'spark big data hadoop',
#  'digital marketing web marketing content marketing google analytics',
#  'matlab opencv image processing dsp electrical engineering intellectual',
#  'sql oracle python analytics data migration postgresql',
#  'head online marketing online marketing acquisition seo analytics sms',
#  'competitive analysis civil engineering technical services',
#  'itil system analysis technical support code review development testing',
#  'cold calling digital marketing social media sales process smo',
#  'saltstack redis nosql nginx docker linux machine learning kubernetes',
#  'sql server ssis ssas oltp etl analysis services software development',
#  'analytics system integration asset management management consulting',
#  'seo keyword research link building google analytics html javascript',
#  'data science big data analytics machine learning python ansible',
#  'static timing analysis rtl design digital design ic design dft',
#  'project planning technical design team leading project management',
#  'collections strategy recovery collections process risk analytics',
#  'xml troubleshooting json maven business process outsourcing git',
#  'market risk risk management var frm basel finance risk analysis',
#  'product consultant customer success marketing',
#  'inventory management warehouse management business operations',
#  'accounting operations accounts payable accounts receivable',
#  'credit rating business analysis financial analysis business research',
#  'c sql server design patterns c unit testing high frequency trading',
#  'secondary research business research primary research project management',
#  'part time freelancing data entry present job work home',
#  'advanced analytics statistical modeling linear regression statistics',
#  'sas data integration consultant sas data integration sas bi',
#  'auditing forecasting research associate process improvement',
#  'ansible python aws azure cloud linux',
#  'spark hive scala hadoop python techno functional sas',
#  'gl accounting sap fico sap finance copa profitability analysis',
#  'sql business intelligence r business development data analytics',
#  'sql data analysis text mining sas r statistical modeling',
#  'customer management customer service identity access management conflict',
#  'report team leading team handling team management sas advance sas sql',
#  'design development performance testing big data core java spark kafka',
#  'product strategy conferences secondary research technical documentation',
#  'recruitment talent acquisition mapping need analysis capacity planning',
#  'molecular biology biotechnology toxicology web technologies',
#  'analytics python project management modeler predictive modeling',
#  'account management sales strategic planning install base',
#  'business analysis ehr emr user stories healthcare agile sdlc',
#  'peoplesoft hcm peoplesoft hrms peoplesoft fscm peoplesoft finance',
#  'banking analytics team leading credit cards business intelligence',
#  'user ux product management customer new product',
#  'ui development html native software engineering react js css',
#  'sql queries data science arima analytics machine learning',
#  'project management pmp prince solutioning infrastructure',
#  'asset accounting finance co sap fico profitability analysis ap profit',
#  'project management product engineering product development',
#  'sql excel powerpoint r vba mysql python data analysis',
#  'data entry operation typing excel notepad freelancing content writing',
#  'accounting book keeping reconciliation',
#  'verilog vhdl rtl compiler dft design engineering failure analysis',
#  'invoice processing vendor management bank reconciliation',
#  'endeca atg commerce atg e commerce java atg atg implementation',
#  'sql multithreading ooad coding debugging investment banking',
#  'spark hive hadoop scala java big data machine learning python rest',
#  'new business development corporate strategy strategic planning financial',
#  'application development senior analyst',
#  'neural networks r python big data analytics data analysis',
#  'deep learning machine learning text mining computer vision analytics',
#  'sales management business development management lead generation',
#  'presales digital marketing digital strategy rfp sales alliances',
#  'analytics manager analytics python consulting marketing analytics',
#  'analytics business operations business process data modeling',
#  'portfolio manager wealth manager wealth advisor investment advisor',
#  'marketing communication brand management atl btl social media marketing',
#  'oracle telecom business analysis togaf documentation tools',
#  'pega prpc java bpm application development business rules',
#  'sap bi ui development business process outsourcing analytical',
#  'liquidity treasury treasury operations forex operations',
#  'global procurement purchase management sourcing negotiation',
#  'detailing communication skills data migration business analysis',
#  'project management project delivery solution architecting agile',
#  'debugging business process outsourcing operations pwd j ee analytical',
#  'spark project management big data rfps solution design',
#  'ar calling ar analyst accounts receivable revenue cycle management',
#  'data analysis outsourcing operations continuous improvement',
#  'erp functional functional consultancy data processing data management',
#  'project management technology solutions scope solution architecture',
#  'android sql software architecture software design design patterns',
#  'financial services financial analysis business analysis balance sheet',
#  'enterprise risk management internal audit sox auditing',
#  'business analysis business process outsourcing business strategy',
#  'digital marketing ecommerce sales brand marketing marketing',
#  'high frequency trading market making quant trader market maker',
#  'excel data analysis sql segmentation data analytics statistics',
#  'business development b b sales corporate sales marketing planning',
#  'python c quantitative research statistical analysis statistics',
#  'advanced analytics statistical modeling linear regression statistics',
#  'python machine learning digital marketing forecasting',
#  'deep learning natural language processing machine learning nlp python',
#  'process improvement auditing analytical interpersonal skills accounting',
#  'digital marketing promotions segmentation e commerce',
#  'pay per click google adwords ppc campaigns search engine marketing',
#  'business development strategic planning strategy consulting b b',
#  'finance financial planning revenue planning information analysis',
#  'area credit manager area credit lap credit underwriting',
#  'predictive analytics data visualization excel sql data analytics',
#  'analytical formulation six sigma procurement ms office agrochemical',
#  'java technical architecture etl enterprise architect',
#  'sas sql chaid logistic regression anova excel r time series',
#  'sales planning business development sales development zonal',
#  'executive search people management account management leadership hiring',
#  'retail sales marketing consumer durables sales planning sales process',
#  'banking analytics customer management customer service orientation',
#  'product manager speech analytics ml ai deep learning nlp',
#  'dataanalyst analyst backoffice operations data entry backend',
#  'presales biztalk stored procedures consulting sdk microsoft dynamics',
#  'data analysis sql consulting data management spss fmcg analytical',
#  'android kotlin',
#  'sales executive activities negotiation skills analytical instruments',
#  'safety environment occupational health head projects health',
#  'bpo customer support customer service fresher freshers backend',
#  'agile scrum master business analysis requirements',
#  'cluster analysis factor analysis sas time series analysis r',
#  'hr analytics investment banking human resource management finance',
#  'use cases neural networks data analysis r time series data mining',
#  'hdfs mapreduce hadoop big data access management monitoring tools',
#  'hr executive onboarding joining formalities exit formalities',
#  'logistics operations warehouse management auditing inward stock audit',
#  'marketing strategy sales management sales forecasting territory growth',
#  'financial analysis month end reporting market research cost control',
#  'project management strategic planning management consulting',
#  'risk management sas sql credit risk wholesale banking risk analytics',
#  'business development management presentable analytical skills',
#  'real estate',
#  'design analysis customer satisfaction design development',
#  'seo digital marketing google adwords keyword research ppc',
#  'strategic planning business consulting data analysis media planning',
#  'sales management marketing iim building material project management',
#  'marketing automation digital marketing email marketing',
#  'project management c strategy technology solutions client engagement',
#  'logistic regression linear regression sas factor analysis',
#  'internal audit ifc enterprise risk management auditing risk compliance',
#  'fund raising ngo financial forecasting donor acquisition',
#  'back office processing back office executive back office assistant',
#  'hadoop hive data science spark machine learning r python big data',
#  'sas sql machine learning r data extraction excel python',
#  'obiee oracle business intelligence obi oracle bi obiee developer',
#  'c azure tfs project management people management go getter',
#  'data science data analytics statistical analysis tableau data modeling',
#  'inventory valuation product costing cost audit mis reporting auditing',
#  'tender site biil boq quantity surveying rate analysis quantities',
#  'c algorithm solution design technical design software development',
#  'financial accounting finance accounts payable general ledger auditing',
#  'impact analysis data modeling business analysis business solutions',
#  'online marketing marketing campaigns promotional campaigns web analytics',
#  'para legal paralegal trademark patent intellectual property ip ipr',
#  'banking credit cards personal loans mis development senior management',
#  'financial analysis financial planning financial modelling pricing',
#  'text mining r machine learning sas logistic regression sql',
#  'sql etl dw bi plsql data migration analytics business analysis',
#  'deep learning machine learning text mining computer vision analytics',
#  'sas logistic regression chaid r data analytics anova excel',
#  'voice process call center bpo tele caller tele sales outbound sales',
#  'quant trader trader trading research data structures algorithms',
#  'cloud computing user xperience artificial intelligence ai chatbots',
#  'ahu maintenance hvac chillers technical support energy audit',
#  'r c machine learning data analytics python deep learning',
#  'supply chain senior management business intelligence',
#  'adobe analytics digital marketing digital analytics web analytics',
#  'senior hr human resource management workers compensation',
#  'linux perl networking python vmware testing tools ruby analytics',
#  'verbal communication communication skills software quality',
#  'deep learning natural language processing machine learning nlp',
#  'project management scrum process consulting cmmi software development',
#  'manual testing qa quality analyst networking linux',
#  'access excel data analysis report generation data integrity',
#  'net c c net quantitative analysis investment management analyst',
#  'inbound outbound international bpo chat process customer care customer',
#  'typing speed analytical skills communication skills',
#  'hedge funds finance fund administration derivatives risk management',
#  'lead drupal develoer drupal drupal technical lead',
#  'senior analytics analyst bigdata spark gurgaon hr',
#  'customer marketing content creation customer',
#  'digital marketing sem web analytics marketing campaigns swot analysis',
#  'xml html epub css xslt team leader',
#  'sales strategic planning account management install base',
#  'recruitment screening interviewing hiring hr benefits',
#  'search engine optimization analysis seo writing seo analyst seo expert',
#  'finance financial management budgeting forecasting financial reporting',
#  'finance financial reporting financial analysis forecasting',
#  'big data analytics consulting strategy corporate strategy',
#  'software development software design design patterns product management',
#  'execution analytical skills strategy analyst',
#  'project management technical architecture scope plant maintenance',
#  'sql database tableau big data sap bo power bi plsql',
#  'google adwords marketing budget google analytics display advertising',
#  'test strategy test reporting test cases test case execution test lead',
#  'cyber security technical support network security security',
#  'business strategy growth strategy profit optimization operating model',
#  'mis html xml vb macros information security analytical ms sql',
#  'management accounting fpa management reporting performance management',
#  'recruiter recruitment hr human resource talent acquisition',
#  'social media marketing lead generation consumer insights',
#  'maintenance activities general management operations preventive',
#  'personal assistance secretary executive assistant personal assistant',
#  'istqb automation testing test planning cste sdlc quality analysis',
#  'erp implementation gap analysis business process erp system',
#  'python data mining machine learning business process outsourcing',
#  'production engineering plastic extrusion injection moulding',
#  'accounting internal audit auditing enterprise risk management big',
#  'finance financial planning financial analysis forecasting budgeting',
#  'django python javascript mongodb nosql software development linux',
#  'bpo accounting mba finance financial reporting financial planning',
#  'secondary research company profiling market sizing primary',
#  'ppc google adwords facebook google analytics linkedin',
#  'business analysis business analytics collections strategy',
#  'auditing accounting payroll processing statutory compliance',
#  'business analyst team leader system engineer software functionality',
#  'fraud analytics people management skills team leading problem solving',
#  'google analytics ppc marketing management google adwords adwords',
#  'content writing editing content editing content development editing',
#  'project management program management predictive analytics',
#  'automation testing qtp test scripts test engineering',
#  'data science analytics data mining machine learning factor analysis',
#  'hadoop hive java spark cassandra sql scala redis elastic search',
#  'sas logistic regression predictive modeling model validation lgd',
#  'data entry operation typing excel notepad freelancing content writing',
#  'secondary research market research report writing primary research',
#  'qc quality control chemical qc chemical quality assurance chemical',
#  'quantitative research project management quantitative analysis',
#  'valuation finance portfolio analysis credit risk financial modelling',
#  'technical support tech support technical support executive',
#  'legal agreements lease abstraction lease admin lease abstraction',
#  'sas logistic regression chaid r data analytics anova excel',
#  'business development sales lead generation cold calling inside sales',
#  'email marketing lead generation digital marketing business development',
#  'plumbing electricals mep service delivery customer category',
#  'quality assurance test engineering test data quality testing analytical',
#  'product manager product management application development sdlc feature',
#  'part time freelancing data entry present job work home',
#  'delay analysis forensic planning claims risk management arbitration',
#  'sql data modeling data integration supply chain planning',
#  'segmentation correlation banking finance analytics clustering ranking',
#  'accounting operations finance auditing payables',
#  'iit iim digital technology blockchain iot ai ml entrepreneur b b',
#  'institutional equity reserach analyst equity research',
#  'hr generalist recruitment agency hr exit management vendor management',
#  'project management client management team management strategy consulting',
#  'digital marketing keyword research online marketing google analytics',
#  'javascript json angularjs html rest java spring framework git front',
#  'json html java xml software development jsp aem cq',
#  'quality control qc management quality assurance haccp',
#  'ar calling medical billing us healthcare senior ar associate',
#  'corporate sales b b sales b b business business leadgeneration',
#  'sas r business analytics predictive modeling linear regression',
#  'financial accounting mba finance financial management consolidation',
#  'marketing sales design engineering user competitive analysis',
#  'spss statistical software data analysis sas alteryx tableau',
#  'machine learning data analysis predictive analytics algorithms python',
#  'android agile methodology product life cycle performance analysis',
#  'part time freelancing data entry present job work home',
#  'business process analysis business analysis business research',
#  'sales support marketing presales business intelligence market research',
#  'java nosql mysql mongodb scala spark hadoop python git mapreduce',
#  'marketing sales competitor analysis market research events region',
#  'sas consulting digital marketing econometrics regression analysis',
#  'spark mapreduce big data analytics scala data integration',
#  'high frequency trading trading hft quant trading head market making',
#  'javascript jquery wcf plsql mvc web development debugging',
#  'heor health economics rwe real world data healthcare pharma analytics',
#  'marketing analysis market research strategy social media data analysis',
#  'accounting general ledger accounts receivable sql data analytics fraud',
#  'employee engagement hr training learning training analysis',
#  'visualization analytics ms sql teradata olap etl hadoop hive impala',
#  'xml html web services agile json css front end version control git',
#  'part time freelancing data entry present job work home',
#  'competitive analysis interpersonal communication rf testing radra expert',
#  'mysql nosql linux system administration rackspace cassandra',
#  'digital marketing seo web promotion web marketing internet marketing',
#  'content marketing advertising social media marketing twitter sales',
#  'management accounting finance us gaap ifrs financial auditing',
#  'financial analysis financial planning budgeting variance analysis',
#  'travel arrangements vendor management office management housekeeping',
#  'biology zoology botany medical coding medical coder',
#  'pig hive hadoop spark big data shell scripting software engineering',
#  'project management procure pay source contract invoicing accounts',
#  'field rewards hr analytics business partners hr consulting compensation',
#  'hive spark flume cloudera sqoop hdfs data science big data yarn',
#  'java core java groovy grails',
#  'business analysis e tendering bidding techno commmercial',
#  'predictive analytics inventory optimization demand planning r',
#  'social media digital communication content editor content writer nism',
#  'c biztalk server msmq entity framework wcf sharepoint server c net',
#  'infrastructure data center management management operations',
#  'project management pmp manager quality assurance quest qa',
#  'bi analytics',
#  'agile analytics business process outsourcing portfolio management',
#  'sql r python tableau analytics business intelligence data analysis',
#  'java android object oriented design nfc threading',
#  'manufacturing industry erp navision exposure cost analysis',
#  'product strategy marketing sales b c product management b b',
#  'salesforce salesforce com force com solution architecture',
#  'cost accounting finance budgeting auditing product costing',
#  'hadoop java data science cloudera spark hive impala presales',
#  'real estate accounts development rf part time technical support',
#  'sas sql r statistical modeling risk analytics statistics',
#  'hadoop hive flume oozie sqoop hdfs spark pig hbase yarn avro',
#  'business analyst senior business analyst sr business analyst sr ba',
#  'data science hadoop machine learning spark python hive sql database',
#  'google adwords google analytics email marketing',
#  'pmp outsourcing excel operations operations management',
#  'business process internal audit six sigma black belt',
#  'java ee hibernate spring javascript mysql open source',
#  'lgd ccar risk modeling banking sas model development analytics ead',
#  'procurement management logistics supply chain market analysis',
#  'online marketing excel ppc cpa analytical skills us inbound sales',
#  'acquisition strategy analytics strategy clustering segmentation',
#  'r logistic regression sas machine learning segmentation python',
#  'digital marketing social media marketing google analytics google adwords',
#  'research market research business research company profiling',
#  'financial analysis credit rating finance financial sector',
#  'javascript jquery angularjs html css node js adobe analytics',
#  'text mining machine learning r data mining sas logistic regression',
#  'supplier quality qms internal audit wires six sigma',
#  'clinical research biotechnology microbiology zoology biomedical bhms',
#  'accent process compliance quality standards customer',
#  'banking credit cards personal loans mis development senior management',
#  'credit credit analyst credit manager credit officer lcv hcv',
#  'shell scripting coding customer service telecommunication',
#  'page optimization page optimization google analytics seo',
#  'financial modelling business strategy finance feasibility studies',
#  'sas visual analytics consultant sas sas programming',
#  'ms project problem solving compliance issue operational metrics jira',
#  'content writing technical writing content management content designing',
#  'shell scripting analytics business process outsourcing scala',
#  'manager research scientist machine learning data modeling',
#  'excel',
#  'quality assurance engineering qa qc engineer quality control engineer qa',
#  'product management technical documentation strategy',
#  'sql server software development oracle sql product testing',
#  'digital marketing business development seo sem css html web analytics',
#  'sales business development management presales client engagement',
#  'insurance underwriting underwriting team leader back office operations',
#  'customer segmentation advanced excel sql business analysis',
#  'web content journalism content writing editorial seo content strategy',
#  'seo search engine optimization pay per click google adwords professional',
#  'six sigma green belt process excellence quality analysis',
#  'accounting finance general ledger excel word payroll processing',
#  'mba finance business intelligence mcom',
#  'sap mm analytics outsourcing downstream operations',
#  'data analysis data analyst statistics analytics data analytics problem',
#  'sas sql business analysis analytics r data mining reject inference',
#  'performance appraisal hr training self service branch banking',
#  'ssrs ms sql server ssas power bi data warehousing',
#  'digital marketing webtrends web analytics google analytics social media',
#  'python data mining machine learning outsourcing django analytical',
#  'seo search engine optimization',
#  'accounting internal audit auditing risk advisory',
#  'sql server azure design patterns data reporting team management skills',
#  'project management client engagement business analysis',
#  'hr information system project management project planning payroll',
#  'gap analysis visio excel data mapping administration team leading',
#  'technical business analysis requirement gathering ms office requirement',
#  'project management spend management supplier relationship management pmo',
#  'data analytics sql database data extraction root cause analysis problem',
#  'credit underwriting credit analysis credit management risk management',
#  'smm seo search engine optimization sem search engine marketing',
#  'order management risk management business process outsourcing',
#  'sta timing timing closure timing analysis primetime prime time',
#  'design development development testing knowledge management',
#  'assistant manager accounting hyderabad ts',
#  'google adwords keyword research google analytics digital marketing page',
#  'net c software engineering unit testing technical design',
#  'product management product strategy product marketing user',
#  'hplc gc dissolution tester uv analytical method validation',
#  'business analyst oracle informatica project management agile pega',
#  'microsoft business process scheduling outsourcing operations',
#  'finance management reporting budgeting financial analysis forecasting',
#  'java spring mvc hibernate j ee maven tomcat web services',
#  'infrastructure data center management management operations',
#  'spring hibernate j ee core java hadoop nosql spark',
#  'business excellence black belt automation minitab robotics',
#  'qtp selenium jmeter sql load runner test scripts test management tool',
#  'marketing competitor analysis international business international sales',
#  'nmr hplc gc ir research analytical techniques process development',
#  'node js javascript css html neo j java git python docker',
#  'sdlc business analysis filenet investment banking test cases',
#  'javascript python bash docker aws azure web technologies',
#  'purchase excel vendor development modeler ms office cost reduction',
#  'predictive modeling logistic regression r sas predictive analytics',
#  'sql data modeling etl data warehousing data governance',
#  'seo smm affiliate marketing sem digital marketing google analytics',
#  'asset accounting internal orders gl accounting profit centre sap fico',
#  'catastrophe cat model catastrophe modelling catastrophe modeling',
#  'data science data scientist machine learning r python',
#  'information retrieval java algorithms data science spark sql',
#  'project management project finance financial modelling budgeting',
#  'python sas',
#  'capital markets mathematical models valuation r matlab spss cart',
#  'big data data engineer big data engineer senior hadoop developer python',
#  'communication analytical skills interpersonal skills problem solving',
#  'use cases test cases requirement gathering test planning sdlc',
#  'uml automation flex manager quality assurance lan application support',
#  'international bpo communication skills quality analysis sox compliance',
#  'customer service bearings lubricants vapi vibration analysis condition',
#  'operational tax tax implications tax international tax',
#  'sql sas macros unix continuous improvement business reporting',
#  'java android sdk android development parsing mobile development json',
#  'statistical modeling r neural networks machine learning sas sql',
#  'ux ui designer adobe photoshop illustrator axure sketch',
#  'product management pricing strategy market analysis product development',
#  'rfp presales software services analytical skills brd frd gap analysis',
#  'manager process excellence analytics process excellence analytics',
#  'warehouse inventory warehouse operations supply chain',
#  'excel sql data analysis segmentation sas data mining spss',
#  'excel mis analytical skills manager mis manager mis reporting',
#  'management consulting business consulting corporate strategy',
#  'performance tuning analyst test execution performance tuning performance',
#  'private equity sell side investment banking finance financial modelling',
#  'medical coding cpc cic coc ccs anesthesia anaesthesia e pathology',
#  'grunt javascript karma apache cordova couchdb spring redis java',
#  'head hunting recruitment screening leadership hiring hr',
#  'ansible linux devops aws jenkins',
#  'head contact center quality customer service delivery auditing process',
#  'secondary research business research market sizing research analysis',
#  'seo digital marketing google analytics sem keyword research',
#  'investment banking fund accounting reconciliation mutual funds cash',
#  'data reporting data analytics ms office vba macros pmo',
#  'direct sales marketing analytics branding team management',
#  'sas analytics statistical analysis compensation analytics',
#  'engineering change management semiconductor manufacturing',
#  'production planning control operations management quality standards team',
#  'company secretary legal secretarial activities analytical skills',
#  'modeller predictive modeling market mix modellling data science sql',
#  'sas linear regression credit risk management r predictive analytics',
#  'oracle plsql stored procedures data analysis business process',
#  'sql data analytics data analysis excel data mining marketing analytics',
#  'basel iii rwa business finance market risk credit risk derivatives',
#  'hibernate spring java multithreading sql software development',
#  'scala machine learning java python sql r pig data mining perl',
#  'marketing lead generation sales competitor analysis digital marketing',
#  'java j ee software development software engineering agile development',
#  'seo digital marketing search engine optimization business development',
#  'data analysis predictive modeling data mining sas data analytics',
#  'arc objects net java map',
#  'financial management finance maintenance project operations',
#  'store management store operations promotions visual merchandising',
#  'advanced excel mis data analysis retail outlets mis executive',
#  'sales marketing campaigns promotions advertising market research',
#  'business analysis business intelligence data modeling erwin',
#  'business intelligence data analysis ms access ms office data management',
#  'pricing analysis error rectification customer centric',
#  'garment export export house ca ca qualified',
#  'sas tableau excel r analytics',
#  'financial modelling dcf npv finance budgeting management accounting',
#  'sales equity business analysis finance settlements',
#  'business management analyst business management financial forecasting',
#  'seo sem search engine marketing keyword research web analytics',
#  'advanced analytics sas r data visualization data mining',
#  'finance adhoc testing scrum business process business analysis',
#  'java bootstrap json xml web services oim oracle identity manager',
#  'adl analytical development analytical method development',
#  'customer support polymer testing enviornmental testing',
#  'linear regression machine learning predictive modeling',
#  'javascript json angularjs html rest java spring framework git front',
#  'informatica automation eclipse information technology healthcare',
#  'manual testing black box testing regression testing white box testing',
#  'soc analyst',
#  'java angular html css bootstrap karma jasmine',
#  'stlc manual testing sdlc qa jr qa writing bug report',
#  'finance macros advanced excel vba management reporting mis reporting',
#  'big data solution architecture program management scp iot block chain',
#  'analytics predictive modeling statistical analyst time series analysis',
#  'mystery shopping market research freelancer work home part time',
#  'customer operations sourcing supply chain inventory planning',
#  'hr analytics execution project management data management fixed income',
#  'tableau data analytics data analysis',
#  'sap workflow access management business process outsourcing operations',
#  'deep learning neural networks machine learning',
#  'recruitment hiring hr talent acquisition executive search',
#  'mis mis reporting mis preparation mis updation mis coordinator',
#  'estimation costing budgeting qs quantity surveyor quantity surveying',
#  'c python java algorithms neural networks machine learning scala',
#  'marketing advertising campaigns activation b b keyword research ppc',
#  'sales business development marketing prospecting client relationship',
#  'technical support analyst desktop support hyderabad ts',
#  'qc analytical testing analytical qa',
#  'business development management b b sales marketing initiatives',
#  'procurement auditing accounting finance resource planning process',
#  'sql queries informatica cognos data integration webfocus microstrategy',
#  'cost accounting finance financial accounting inventory accounting',
#  'search engine marketing sem ppc google analytics webtrends omniture',
#  'company research market research finance competitive analysis financial',
#  'process definition cmmi iso quality assurance quality management',
#  'abap business process outsourcing operations export import',
#  'oracle financials oracle fusion user administration revenue management',
#  'data analytics sql statistics r econometrics data mining',
#  'asp net c net mvc sql server jquery software development',
#  'design patterns soap multithreading xml core java agile development',
#  'international call center technical support social media',
#  'seo analysis online marketing internet marketing link building',
#  'sql server data profiling data governance etl tool data quality',
#  'plant operations plant management record keeping report generation soft',
#  'credit risk analytics credit risk credit business architecture',
#  'test cases test analysis performance testing test analyst net c',
#  'corporate sales sales business development',
#  'marketing sales product analysis people management skills',
#  'construction finance housing finance market intelligence data analysis',
#  'sitecatalyst web trends web analytics web analyst ensighten tealium',
#  'jira business process outsourcing resource management agile methodology',
#  'manual testing selenium api testing appium mobile testing testng test',
#  'iot telecom smart cities project management project coordination',
#  'oracle sql unix hana sap basis database windows os',
#  'quality assurance analyst unix windows flex lan application support',
#  'digital analytics',
#  'application lead rest json xml http power bi kibana grafana python',
#  'sales force sap bi ms officems excel analytical skills',
#  'operations management lean six sigma operational excellence',
#  'java rabbitmq j ee redis spring framework cloud foundry junit scala',
#  'testing test engineer manual testing qa test case automation testing',
#  'seo digital marketing google adwords sem affiliate marketing ppc',
#  'sas di base sas analytics campaign management marketing',
#  'sql vb wcf automation application support problem management',
#  'market research healthcare life sciences pharma pharmaceutical medical',
#  'compensation benefits',
#  'digital marketing social media marketing online marketing',
#  'sas unix sas enterprise guide big data hadoop analytics',
#  'project management pmp prince solutioning infrastructure',
#  'seo ppc web development web technologies sem search engine marketing',
#  'onesource business research competitive intelligence bloomberg research',
#  'sql scripting performance tuning database design views consulting',
#  'excel data analytics data collection data management supply chain',
#  'marketing support sales brand strategy marketing analytics',
#  'credit analysis credit risk portfolio management healthcare',
#  'net developer',
#  'digital marketing social media marketing seo google adwords',
#  'training career planning maintenance activities performance management',
#  'sales research analysis equity research investment banking valuation',
#  'analyst financial planning financial services general',
#  'ccar risk management forecasting model development consumer finance',
#  'erp business objects workflow business process outsourcing analytical',
#  'deep learning node js javascript nosql elastic search json artificial',
#  'automation system software operations root cause analysis',
#  'data modeling big data saas analytical engines campaign management',
#  'credit credit documentation credit appraisal credit analyst',
#  'data entry operation data entry operator dataentry customer service',
#  'project management analytics service management outsourcing analytical',
#  'sql predictive modeling r sas analytics statistics tableau',
#  'project management data analysis market research analytics',
#  'process engineering network design modeling',
#  'sql data warehousing business intelligence data integration etl',
#  'sas data management oracle spss cognos business objects',
#  'business analysis use cases business analytics business intelligence',
#  'dcf lbo pitch books financial analysis project finance',
#  'physical design timing closure timing analysis signal integrity',
#  'seo writing google webmaster tools link building page optimization',
#  'java mvc mysql net python scalability sql server web technologies',
#  'learning development consultant induction training',
#  'identity access management auditing iam infrastructure',
#  'sql informatica datastage python production support',
#  'pega consulting information technology recruitment bpo',
#  'ms dynamics crm office skills technical support production support',
#  'health insurance regulatory compliance strong analytical skills legality',
#  'client servicing customer support customer care international bpo voice',
#  'strategy assistant executive assistant corporate strategy marketing',
#  'windows client management oracle unix scheduling incident management',
#  'interface builder objective c ios swift apple software development',
#  'service delivery sql sas consulting assurance continuous improvement',
#  'project management project execution project governance waterfall agile',
#  'hive hadoop flume sqoop oozie sql server impala ssrs solr java',
#  'finance banking financial modelling project funding fund raising',
#  'sales strategy business analysis sales force optimization',
#  'query designer bex analyzer sap bi sap bw sap bo webi',
#  'data analyst pv case processing pharmacovigilance data analysis',
#  'nlp text mining data science text analytics python r claims analytics',
#  'adobe analytics strategy web analytics data integration',
#  'research analysis executive assistant data analytics',
#  'captivate photoshop flash ilt illustrator instructional design wbt',
#  'analytical skills machine learning optimization problem solving',
#  'unit testing test cases javascript jquery css bootstrap php jsp',
#  'financial accounting finance budgeting taxation financial reporting',
#  'analytics predictive modeling scm analytics',
#  'google analytics ad tags google tag manager doubleclick publishers',
#  'adobe analytics web analytics digital analytics digital marketing',
#  'sales promotion marketing initiatives primary sales sales management',
#  'seo digital marketing sem smm social media marketing',
#  'model validation monthly reports cash equities',
#  'part time freelancing data entry present job work home',
#  'digital marketing seo google adwords sem social media marketing',
#  'c c vc linux os design patterns team leading capital market',
#  'fund accounting finance us gaap ifrs auditing fixed income derivatives',
#  'seo analysis digital marketing internet marketing online marketing',
#  'data analytics data reporting data cleansing troubleshooting skills',
#  'visualforce sfdc triggers salesforce salesforce developer',
#  'market research business research market analysis strategy consulting',
#  'qualitative research manager market research marketing',
#  'corporate business development marketing sales strategy franchising',
#  'seo sem display advertising digital marketing google analytics',
#  'project management healthcare analytics scope consulting project design',
#  'product design software development life cycle software solutions',
#  'quality evaluator international bpo domestic bpo quality analyst qc qa',
#  'product marketing machine learning python r marketing operations',
#  'sas logistic regression predictive modeling model validation lgd',
#  'marketing sales analysis operations management branding',
#  'webtrends adobe analytics media marketing web analytics',
#  'fraud analytics people management skills team leading problem solving',
#  'credit control treasury ca chartered accountant audit',
#  'business process gap analysis integration services uat',
#  'merchant services business analyst html php apis workflow design',
#  'analytics sas people management p c analytics analytics head',
#  'banking analytics team leading problem solving retail business sas',
#  'text mining hive nosql python r sql data analysis machine learning',
#  'corporate sales general insurance strategy development analytical skills',
#  'jquery',
#  'project management program management predictive analytics',
#  'analytics fixed income bloomberg derivatives quantitative models',
#  'sap fico consultant cost element accounting cost center accounting copa',
#  'user stories scope visio project management business analysis',
#  'accounting finance control mis ms office statutory reporting',
#  'key accounts relationship management go getter supply chain',
#  'html xml javascript web services mvc java soap ms sql server uddi',
#  'sas predictive modeling segmentation model development scorecard',
#  'technical sales solution architecture technical architecture java',
#  'media buying digital marketing sales branding media planning',
#  'deep learning data science predictive analytics sql data visualization',
#  'project management pmi program management sales scope',
#  'content marketing email marketing digital marketing seo',
#  'analytics service management outsourcing operations orchestration',
#  'text mining r time series analysis machine learning sas',
#  'recruitment hr executive search hiring talent acquisition',
#  'sap hana native hana hana modelling xsjs xso xsodata',
#  'quantitative analysis manpower management',
#  'hadoop hive spark big data cost benefit analysis samza kafka',
#  'content marketing product sales marketing automation product management',
#  'hadoop hive sql spark impala scala nosql java big data hbase',
#  'django mysql python redis mongodb postgresql git rest svn',
#  'edi us healthcare edi analyst electronic data interchange analyst',
#  'quantitative research risk analytics quantitative analysis fixed income',
#  'javascript jquery redis rest mysql git aws ci api web technologies',
#  'sap basis business process outsourcing analytical operations',
#  'sql apache python data modeling business process outsourcing hbase',
#  'unix scripting base sas analytics itil framework production support',
#  'spark big data scala hadoop python hadoop developer',
#  'enhancements uat mba finance business analysis investment management',
#  'business analyst business analysis sql user stories ui mock ups',
#  'agriculture enterprise sales marketing analytics business analytics',
#  'accounting business finance risk assurance auditing taxation financial',
#  'oracle web services extjs business process outsourcing git mongodb',
#  'sales strategy business development marketing channel partners',
#  'accounting finance journal entries fixed assets financial statements',
#  'relationship management customer service sales executive sales marketing',
#  'web analytics tracking conversion rates seo web metrics analysis',
#  'campaign analytics data analysis sas programming data management',
#  'bpo international voice voice process quality analysis quality analyst',
#  'associate sap bpc sap consulting system integration consulting sap',
#  'gap analysis visio excel data mapping administration team leading',
#  'linear regression insurance analytics business analysis',
#  'c c wpf software engineering delphi database team skills',
#  'mobile apps designer',
#  'data science finance quantitative analysis analytical skills',
#  'product marketing customer retention product roadmap',
#  'deep learning natural language processing machine learning',
#  'coaching offline teaching offline lecturer offline faculty',
#  'insurance broking general insurance data analytics sql',
#  'cad staad pro structural analysis design review autodesk recruitment',
#  'nosql spark mapreduce cassandra sql scala microsoft azure mongodb',
#  'version control computer science professional services',
#  'design trend analysis jewellery designer jewelry gems jewellery',
#  'user ux product management customer new product',
#  'bigdata analytical support engineer big data stack power bi tableau',
#  'business development executive',
#  'product marketing sql data analytics data analysis segmentation r',
#  'java nosql mysql mongodb graphite scala clojure ansible ruby',
#  'manager model development analytics portfolio risk reporting',
#  'accounting auditing corporate finance internal audit forensic audit',
#  'information security soc outsourcing siem infrastructure security',
#  'data analytics mis business analytics analytics wealth management b b',
#  'sap mm sd master data procurement fi invoice verification third party',
#  'java javascript algorithms github cassandra front end backend',
#  'costing mis budgeting balance sheet p l cost audit report tph',
#  'report generation management reporting mis management information system',
#  'research market research business research company profiling',
#  'aem aem aem adobe manager adobe cq osbi',
#  'ar ap medical billing voice process international bpo',
#  'wealth management customer focus analytics pricing',
#  'analytics machine learning tensorflow pytorch python libraries',
#  'project delivery oracle mysql sql object oriented analysis agile',
#  'sales management customer service auditing information security',
#  'content writing seo analysis seo writing sem analyst digital marketing',
#  'data visualization big data analytics data management statistics',
#  'java json node js soap html nosql machine learning spring',
#  'business development management sales marketing strategic alliances',
#  'assortment planning sales vendor management category management',
#  'sql data analysis unix data processing presentation skills athena',
#  'team management customer management gap analysis issue resolution',
#  'medical coding bds bpt health care medical coding jobs chennai',
#  'procedures customer satisfaction research analysis quality assurance',
#  'sales planning forecasting analytics salesforce',
#  'business analyst gsm billing crm interconnect roaming oss bss',
#  'marketing automation customer analytics iim tableau data analytics',
#  'corporate finance financial modelling valuation portfolio management',
# ...
#  'quality audit quality assurance quality analysis feedback',
#  'manager supply chain analytics supply chain analytics vba',
#  'accounting finance financial analysis credit policy credit analysis',
#  'mass production qa management qms ehs management iso ts',
#  'joining formalities recruitment hiring vms market research msp',
#  'excel hr reporting data analysis analytics vba data visualization',
#  'logistics supply chain pharma customer service outbound claims',
#  'auditing warehouse management standard operating procedures stock audit',
#  'contract management contract drafting contract negotiations redlining',
#  'sql wcf flex lan application support mvc sdlc middleware coding',
#  'process associate senior process associate bpo non voice email support',
#  'technical voice process bpo voice technical support root cause analysis',
#  'accounting standards indirect taxation auditing finance working capital',
#  'photoshop illustrator seo html inbound marketing hubspot',
#  'ips siem rsa envision asa firewall soc security operation centre pim',
#  'qa analysis software qa',
#  'mysql mongodb puppet php kvm openstack aws open source python perl',
#  'procurement purchase ariba buyer e sourcing procurement officer',
#  'sql health insurance life insurance actuarial project management',
#  'postgresql data warehousing java nosql open source ms sql server data',
#  'sas sdtm adam statistical programming statistics life sciences',
#  'design engineering product management product development',
#  'credit credit analyst credit manager credit officer lcv hcv',
#  'report studio analysis studio query studio framework manager cognos bi',
#  'strategic analytics analytics customer management banking portfolio',
#  'international call center international bpo domestic ticketing',
#  'algorithms data structures microsoft azure aws google cloud rackspace',
#  'medical coding medical coder zoology microbiology biotechnology',
#  'cold calling inside sales marketing executive pre sales executive',
#  'management accounting commercial management mis procurement',
#  'mongodb java mysql nosql elastic search ansible cassandra docker',
#  'project finance financial modelling project appraisal financial analysis',
#  'secretarial activities secretarial skills typing communication skills',
#  'marketing campaigns promotions events marketing management',
#  'sql tsql sql triggers stored procedures cursor msbi ssis ssrs',
#  'channel sales salesforce primary strategy customer business',
#  'rural finance financial analysis credit underwriting credit risk',
#  'r big data analytics predictive modeling neural networks use cases',
#  'commercial budgeting mis modern trade customer reconciliation finance',
#  'adobe analytics aka omniture sitecatalyst site catalyst',
#  'performance engineering networking protocols bash scripting openstack',
#  'networking sql investment banking process improvement cfd',
#  'software development software engineering java software design software',
#  'cyber security',
#  'sales sas r hr analytics human capital machine learning',
#  'predictive analytics data science r neural networks machine learning',
#  'design development',
#  'bpo kpo mnc medical billing process associate us healthcare',
#  'php magento web content blogs html articles ux user',
#  'java j ee quality management system quality management java j ee',
#  'data analysis advance analytics logistics regression',
#  'offline online part time home base work home freelancer',
#  'offline online part time home base work home freelancer',
#  'java j ee azure dockers kubernetes chef j ee servlet sql pl sql',
#  'seo analysis smo social media optimization search engine optimization',
#  'accounting mba finance financial analysis financial reporting financial',
#  'sql javascript excel vlookup countif data validation vb vba triggers',
#  'networking disaster recovery investment management change control',
#  'channel sales event marketing distribution network direct sales channel',
#  'c aws cloud computing scalability azure automation testing',
#  'r excel sas analytics business consulting business consultant',
#  'front end ui angular js html css javascript css jquery react js',
#  'computer vision machine learning distributed computing algorithms ocr',
#  'credit analysis corporate credit credit appraisal credit rating finance',
#  'project planning psd business process outsourcing dialog programming',
#  'data analytics data modeling data mining data extraction senior analyst',
#  'hr operations onboarding induction compensation payroll management',
#  'high frequency trading trading trading strategies design testing trade',
#  'accounting financial services uk payroll uk payroll processing',
#  'content writing seo analysis seo writing sem analyst digital marketing',
#  'salesforce user acceptance testing business analysis business analyst',
#  'crm data quality data reporting saas data analytics business analytics',
#  'research lcms bioanalytical method development',
#  'systems analyst systems analysis ui ux siebel',
#  'artificial intelligence machine learning java supply chain planning sap',
#  'forecasting business management data analytics reporting analytics',
#  'jenkins continuous integration problem solving quality tools root cause',
#  'cost accounting standard costing budgeting finance inventory valuation',
#  'ssrs ssas msbi dw',
#  'j ee java project management java j ee developmen java j ee project',
#  'project estimation project proposal tableau python r bi',
#  'bpo customer service recruitment consulting financial services vpn',
#  'hr head hr hr operations payroll payroll ops budgeting compensation',
#  'seo analysis google webmaster tools page optimization',
#  'postgresql mysql javascript excel xml sql data mining data analysis',
#  'taxation gst indirect taxation',
#  'strategy consulting analytical skills management consulting',
#  'analytics project planning business process data quality outsourcing',
#  'ad sales digital sales media sales online advertising ad operations',
#  'marketing initiatives market intelligence strategic business planning',
#  'finance auditing hr taxation compensation leave payroll software',
#  'json microsoft azure java product marketing xml web services',
#  'accounting project finance financial analysis financial planning',
#  'computer vision deep learning c image processing algorithms',
#  'sql queries data science arima analytics machine learning',
#  'business analysis servicenow',
#  'production support application support technical support teradata',
#  'use cases sales process business development business analysis',
#  'uat business analysis project documentation business analyst',
#  'r machine learning customer analytics python data analytics',
#  'biw design vpm catia dmu dfmea nx cae exterior fe analysis seating',
#  'text mining machine learning r predictive modeling sas',
#  'sas coding data mining business intelligence analytical',
#  'product sales bd presales cisco sales consultant engineer vpn',
#  'financial reporting month end reporting direct tax budgeting',
#  'excel sql data analysis segmentation sas data mining spss',
#  'primavera p primavera unifier primavera analytics primavera tester',
#  'pharmacovigilance meddra medical coding bhms bams pv drug safety',
#  'financial planning financial analysis financial reporting',
#  'r neural networks sas sql machine learning advanced analytics python',
#  'oscp vulnerability assessment penetration testing vapt networking',
#  'machine learning r hadoop data mining statistical modeling',
#  'javascript django css jquery html pyramid python mongodb nosql',
#  'business analysis visio wireframing excel ms project ms office',
#  'cloud computing spark python azure big data analytics open source web',
#  'operations development seo sem co web development analytics php',
#  'sales crm business applications erp software sales',
#  'web analytics web technologies google analytics dtm',
#  'data analytics data mining data analysis analytics statistical analysis',
#  'deep learning nlp spark information retrieval java python',
#  'matlab c modeler programming technical support',
#  'gl accounting accounts payable general ledger accounts receivable',
#  'marketing sales content designing advanced excel advanced analytics',
#  'digital marketing seo sales web analytics customer iim',
#  'erp consulting chartered accountant ca ca inter erp implementation',
#  'r sql big data analytics logistics predictive analytics',
#  'rfi rfp business development market research bidding consulting',
#  'cyber security cyber forensics hmm isoc edr crowdstrike carbon black',
#  'agile user acceptance testing business analysis business operations',
#  'information security soc outsourcing siem infrastructure security',
#  'process design lean manufacturing plant layout qc tools',
#  'project management costing cost costing',
#  'qa analysis functional testing system testing automation testing',
#  'quality assurance inprocess quality qa validation batch manufacturing',
#  'pain management ar follow ar calling healthcare medical billing',
#  'bpo kpo us shift excel mis preparation mis mis reporting mis officer',
#  'secondary research web research online research content generation data',
#  'full stack engineer full stack elastic search solr sql oracle sql',
#  'customer analytics iim tableau data analytics advanced analytics',
#  'application support production support net msbi',
#  'accounting standards ifrs ca ias inter ipcc ms office',
#  'project accounting finance taxation fixed assets',
#  'rwa financial products balance sheet financial management credit risk',
#  'business development product configuration product positioning',
#  'sales business planning project management strategy',
#  'troubleshooting data analysis manager quality assurance data processing',
#  'semi voice process semi voice non voice non voice process fresher',
#  'quality audit talent development service quality six sigma quality',
#  'outbound inbound marketing advertising post sales communication skills',
#  'abap xslt webmethods nwdi udf performance monitoring business analyst',
#  'lgd sql frm client presentations analytics ead r stata',
#  'statistical software customer service management operations excel sas',
#  'sas chaid factor analysis r predictive analytics text mining excel',
#  'automation testing qtp selenium test scripts software testing',
#  'revenue maximization auditing business development data analytics',
#  'r product sales data analysis data analytics marketing campaigns sql',
#  'db cobol jcl configuration management analytics monitoring',
#  'msc msc freshers organic chemistry msc pass msc pass',
#  'panda nlp machine learning python data analysis consulting',
#  'software development software engineer software developer',
#  'project management solution design process consulting',
#  'strategic marketing planning business development sales',
#  'reporting metrics social media listening esm google analytics facebook',
#  'marketing pr social media campaigns content strategy digital content',
#  'ios developer ios objective c swift xcode information architecture',
#  'hr grievance handling hrbp employee relations onboarding',
#  'rfi presales rfp rfq sales project management proposal preparation',
#  'accounting bank reconciliation debtors tds tally software book keeping',
#  'hr strategy employee engagement talent management talent acquisition hr',
#  'campaign analytics data analysis sas programming data management',
#  'mes apriso hydra oracle sql dot net',
#  'machine learning speech scientist artificial intelligence',
#  'process training customer operations soft skills trainer',
#  'valuation finance portfolio analysis credit risk financial modelling',
#  'gap analysis sap consulting scm logistics business analysis',
#  'data analysis tableau tableau',
#  'financial controller accounting finance business head finance cfo',
#  'management reporting asset management power bi data integrity strong',
#  'html user interface designing javascript jquery web designing',
#  'finance accounting f budgeting mis mis reporting variance analysis',
#  'business analysis system analyst business analyst',
#  'base sas sas programming development testing requirement analysis',
#  'sql unix shell scripting spark nosql big data performance tuning',
#  'deep learning machine learning natural language processing',
#  'business analysis functional consultant sdd sdlc life cycle',
#  'mba finance performance improvement report preparation people management',
#  'marketing competitive analysis market research product management',
#  'sales forecasting sales analysis sales coordination sales co ordinator',
#  'laravel javascript css html json android',
#  'html web tools web technologies seo analysis seo executive',
#  'product strategy product management analytics machine learning',
#  'sap accounting accounts payable invoice processing auditing gst',
#  'java j ee web services portal web technologies software engineering',
#  'trade finance risk mitigation contract administration',
#  'business analysis real estate',
#  'six sigma project management financial services data management pmp',
#  'business development channel development consumer goods',
#  'oracle sql sql database business analysis business analytics net frd',
#  'seo analysis smo blogs twitter youtube content writing',
#  'business analysis real estate property acquisition land acquisition',
#  'spring java hibernate j ee scalability solution design',
#  'android studio java dao xml git continuous integration',
#  'cold calling business development outbound calling outbound sales',
#  'search engine marketing social media marketing online marketing',
#  'adobe analytics javascript webtrends jquery seo google analytics aem',
#  'investment banking technical analysis reporting tools web technologies',
#  'academic research creative writing mba fresher mba marketing',
#  'sap bw sap bi sap hana sap ecc power bi sap sap business intelligence',
#  'networking customer support chat hardware remote support email support',
#  'machine learning python c java r matlab perl predictive modeling',
#  'accounting accounts payable payment processing finance',
#  'health insurance health claims tpa claims management medical',
#  'sip h cucm mgcp voice gateways cisco ip telephony networking',
#  'arcsight soc splunk network analysis application software',
#  'supply chain management scm management working capital',
#  'information retrieval java algorithms data science spark sql',
#  'software development product development software engineering',
#  'security analysis security operations siem solutions vulnerability tools',
#  'android developer java json xml android cloud apis oops core java',
#  'project planning gnatt chart sdlc analytical skills sql server database',
#  'quality analyst qa voice call monitoring',
#  'sql windows agile selenium healthcare jira test management',
#  'spark sql big data hadoop developer hadoop',
#  'project management business transformation business analysis',
#  'multivariate analysis time series analysis cluster analysis modeler',
#  'predictive analytics sql r sas business analytics marketing programs',
#  'cpg cpg analytics cpg data analytics cpg data mining cpg data analysis',
#  'seo digital marketing social media optimization',
#  'java html programming coding category catalog taxonomy',
#  'business process outsourcing analytical operations web services',
#  'hive hadoop oozie spark sql server java financial accounting scala',
#  'us accounting quick books taxation balance sheet auditing profit loss',
#  'advanced analytics sql machine learning data manipulation',
#  'lookup advanced excel pivot table vlookup mis reporting ms office',
#  'oracle ms sql server modeler big data data modeling database design',
#  'data structures algorithms c analytics programming time series',
#  'business finance accounting budgeting taxation',
#  'project development gap analysis technical training project management',
#  'sem search engine marketing ppc cpm cpc cpl cpa',
#  'ess gap analysis mss sap hcm uat user acceptance testing',
#  'hr reporting data analytics data analysis hiring compensation',
#  'mysql javascript web development sitecatalyst web analytics xml java',
#  ...]

# %%
list = ' '.join(wordlist) # conacatenating the all elements  in the list
word_list = list.split() # spliting the words by space to make each word as each element
len(word_list)
# Out:
# ['team',
#  'skills',
#  'communication',
#  'skills',
#  'analytical',
#  'skills',
#  'problem',
#  'solving',
#  'ppc',
#  'logistics',
#  'inventory',
#  'management',
#  'supply',
#  'chain',
#  'management',
#  'procurement',
#  'hr',
#  'analytics',
#  'employee',
#  'engagement',
#  'training',
#  'succession',
#  'planning',
#  'sql',
#  'javascript',
#  'automation',
#  'python',
#  'ruby',
#  'analytics',
#  'machine',
#  'learning',
#  'accounting',
#  'finance',
#  'cash',
#  'flow',
#  'financial',
#  'planning',
#  'statutory',
#  'accounting',
#  'academics',
#  'effective',
#  'communication',
#  'teacher',
#  'training',
#  'academic',
#  'trainer',
#  'fraud',
#  'analytics',
#  'people',
#  'management',
#  'skills',
#  'team',
#  'leading',
#  'problem',
#  'solving',
#  'accounting',
#  'internal',
#  'audit',
#  'auditing',
#  'enterprise',
#  'risk',
#  'management',
#  'big',
#  'esic',
#  'hr',
#  'bonus',
#  'pf',
#  'tds',
#  'payroll',
#  'superannuation',
#  'wages',
#  'leave',
#  'accounting',
#  'standards',
#  'finance',
#  'auditing',
#  'financial',
#  'planning',
#  'test',
#  'data',
#  'data',
#  'science',
#  'business',
#  'analysis',
#  'machine',
#  'learning',
#  'engineer',
#  'banking',
#  'model',
#  'development',
#  'analytics',
#  'people',
#  'management',
#  'skills',
#  'marketing',
#  'automation',
#  'sales',
#  'salesforce',
#  'eloqua',
#  'data',
#  'analysis',
#  'data',
#  'science',
#  'machine',
#  'learning',
#  'r',
#  'big',
#  'data',
#  'predictive',
#  'analytics',
#  'sql',
#  'budgeting',
#  'variance',
#  'analysis',
#  'forecasting',
#  'capex',
#  'spring',
#  'core',
#  'java',
#  'j',
#  'ee',
#  'hibernate',
#  'javascript',
#  'struts',
#  'python',
#  'mysql',
#  'hadoop',
#  'hbase',
#  'digital',
#  'marketing',
#  'netezza',
#  'unix',
#  'sql',
#  'server',
#  'oracle',
#  'sql',
#  'business',
#  'finance',
#  'financial',
#  'control',
#  'business',
#  'rules',
#  'analysis',
#  'information',
#  'retrieval',
#  'hadoop',
#  'hive',
#  'spark',
#  'mapreduce',
#  'scala',
#  'digital',
#  'marketing',
#  'google',
#  'adwords',
#  'marketing',
#  'social',
#  'media',
#  'management',
#  'business',
#  'analyst',
#  'gurgaon',
#  'hr',
#  'business',
#  'continuity',
#  'data',
#  'privacy',
#  'isms',
#  'information',
#  'security',
#  'project',
#  'implementation',
#  'client',
#  'management',
#  'sas',
#  'analytics',
#  'analytics',
#  'sas',
#  'ar',
#  'reconciliations',
#  'finance',
#  'accounting',
#  'working',
#  'capital',
#  'management',
#  'sap',
#  'manual',
#  'testing',
#  'test',
#  'scripts',
#  'performance',
#  'testing',
#  'jmeter',
#  'software',
#  'testing',
#  'sales',
#  'equity',
#  'research',
#  'investment',
#  'research',
#  'investment',
#  'banking',
#  'dcf',
#  'amazon',
#  'e',
#  'commerce',
#  'portal',
#  'handling',
#  'business',
#  'analysis',
#  'finance',
#  'mis',
#  'business',
#  'analysis',
#  'excel',
#  'macros',
#  'analytics',
#  'javascript',
#  'scada',
#  'outsourcing',
#  'python',
#  'operations',
#  'life',
#  'insurance',
#  'actuarial',
#  'actuarial',
#  'analyst',
#  'actuary',
#  'regression',
#  'testing',
#  'machine',
#  'learning',
#  'analytics',
#  'natural',
#  'language',
#  'processing',
#  'javascript',
#  'core',
#  'java',
#  'spring',
#  'mvc',
#  'jsp',
#  'j',
#  'ee',
#  'mysql',
#  'jdbc',
#  'maven',
#  'selenium',
#  'business',
#  'process',
#  'outsourcing',
#  'analytical',
#  'operations',
#  'finance',
#  'insurance',
#  'financial',
#  'services',
#  'data',
#  'manipulation',
#  'actuarial',
#  'spark',
#  'big',
#  'data',
#  'hadoop',
#  'digital',
#  'marketing',
#  'web',
#  'marketing',
#  'content',
#  'marketing',
#  'google',
#  'analytics',
#  'matlab',
#  'opencv',
#  'image',
#  'processing',
#  'dsp',
#  'electrical',
#  'engineering',
#  'intellectual',
#  'sql',
#  'oracle',
#  'python',
#  'analytics',
#  'data',
#  'migration',
#  'postgresql',
#  'head',
#  'online',
#  'marketing',
#  'online',
#  'marketing',
#  'acquisition',
#  'seo',
#  'analytics',
#  'sms',
#  'competitive',
#  'analysis',
#  'civil',
#  'engineering',
#  'technical',
#  'services',
#  'itil',
#  'system',
#  'analysis',
#  'technical',
#  'support',
#  'code',
#  'review',
#  'development',
#  'testing',
#  'cold',
#  'calling',
#  'digital',
#  'marketing',
#  'social',
#  'media',
#  'sales',
#  'process',
#  'smo',
#  'saltstack',
#  'redis',
#  'nosql',
#  'nginx',
#  'docker',
#  'linux',
#  'machine',
#  'learning',
#  'kubernetes',
#  'sql',
#  'server',
#  'ssis',
#  'ssas',
#  'oltp',
#  'etl',
#  'analysis',
#  'services',
#  'software',
#  'development',
#  'analytics',
#  'system',
#  'integration',
#  'asset',
#  'management',
#  'management',
#  'consulting',
#  'seo',
#  'keyword',
#  'research',
#  'link',
#  'building',
#  'google',
#  'analytics',
#  'html',
#  'javascript',
#  'data',
#  'science',
#  'big',
#  'data',
#  'analytics',
#  'machine',
#  'learning',
#  'python',
#  'ansible',
#  'static',
#  'timing',
#  'analysis',
#  'rtl',
#  'design',
#  'digital',
#  'design',
#  'ic',
#  'design',
#  'dft',
#  'project',
#  'planning',
#  'technical',
#  'design',
#  'team',
#  'leading',
#  'project',
#  'management',
#  'collections',
#  'strategy',
#  'recovery',
#  'collections',
#  'process',
#  'risk',
#  'analytics',
#  'xml',
#  'troubleshooting',
#  'json',
#  'maven',
#  'business',
#  'process',
#  'outsourcing',
#  'git',
#  'market',
#  'risk',
#  'risk',
#  'management',
#  'var',
#  'frm',
#  'basel',
#  'finance',
#  'risk',
#  'analysis',
#  'product',
#  'consultant',
#  'customer',
#  'success',
#  'marketing',
#  'inventory',
#  'management',
#  'warehouse',
#  'management',
#  'business',
#  'operations',
#  'accounting',
#  'operations',
#  'accounts',
#  'payable',
#  'accounts',
#  'receivable',
#  'credit',
#  'rating',
#  'business',
#  'analysis',
#  'financial',
#  'analysis',
#  'business',
#  'research',
#  'c',
#  'sql',
#  'server',
#  'design',
#  'patterns',
#  'c',
#  'unit',
#  'testing',
#  'high',
#  'frequency',
#  'trading',
#  'secondary',
#  'research',
#  'business',
#  'research',
#  'primary',
#  'research',
#  'project',
#  'management',
#  'part',
#  'time',
#  'freelancing',
#  'data',
#  'entry',
#  'present',
#  'job',
#  'work',
#  'home',
#  'advanced',
#  'analytics',
#  'statistical',
#  'modeling',
#  'linear',
#  'regression',
#  'statistics',
#  'sas',
#  'data',
#  'integration',
#  'consultant',
#  'sas',
#  'data',
#  'integration',
#  'sas',
#  'bi',
#  'auditing',
#  'forecasting',
#  'research',
#  'associate',
#  'process',
#  'improvement',
#  'ansible',
#  'python',
#  'aws',
#  'azure',
#  'cloud',
#  'linux',
#  'spark',
#  'hive',
#  'scala',
#  'hadoop',
#  'python',
#  'techno',
#  'functional',
#  'sas',
#  'gl',
#  'accounting',
#  'sap',
#  'fico',
#  'sap',
#  'finance',
#  'copa',
#  'profitability',
#  'analysis',
#  'sql',
#  'business',
#  'intelligence',
#  'r',
#  'business',
#  'development',
#  'data',
#  'analytics',
#  'sql',
#  'data',
#  'analysis',
#  'text',
#  'mining',
#  'sas',
#  'r',
#  'statistical',
#  'modeling',
#  'customer',
#  'management',
#  'customer',
#  'service',
#  'identity',
#  'access',
#  'management',
#  'conflict',
#  'report',
#  'team',
#  'leading',
#  'team',
#  'handling',
#  'team',
#  'management',
#  'sas',
#  'advance',
#  'sas',
#  'sql',
#  'design',
#  'development',
#  'performance',
#  'testing',
#  'big',
#  'data',
#  'core',
#  'java',
#  'spark',
#  'kafka',
#  'product',
#  'strategy',
#  'conferences',
#  'secondary',
#  'research',
#  'technical',
#  'documentation',
#  'recruitment',
#  'talent',
#  'acquisition',
#  'mapping',
#  'need',
#  'analysis',
#  'capacity',
#  'planning',
#  'molecular',
#  'biology',
#  'biotechnology',
#  'toxicology',
#  'web',
#  'technologies',
#  'analytics',
#  'python',
#  'project',
#  'management',
#  'modeler',
#  'predictive',
#  'modeling',
#  'account',
#  'management',
#  'sales',
#  'strategic',
#  'planning',
#  'install',
#  'base',
#  'business',
#  'analysis',
#  'ehr',
#  'emr',
#  'user',
#  'stories',
#  'healthcare',
#  'agile',
#  'sdlc',
#  'peoplesoft',
#  'hcm',
#  'peoplesoft',
#  'hrms',
#  'peoplesoft',
#  'fscm',
#  'peoplesoft',
#  'finance',
#  'banking',
#  'analytics',
#  'team',
#  'leading',
#  'credit',
#  'cards',
#  'business',
#  'intelligence',
#  'user',
#  'ux',
#  'product',
#  'management',
#  'customer',
#  'new',
#  'product',
#  'ui',
#  'development',
#  'html',
#  'native',
#  'software',
#  'engineering',
#  'react',
#  'js',
#  'css',
#  'sql',
#  'queries',
#  'data',
#  'science',
#  'arima',
#  'analytics',
#  'machine',
#  'learning',
#  'project',
#  'management',
#  'pmp',
#  'prince',
#  'solutioning',
#  'infrastructure',
#  'asset',
#  'accounting',
#  'finance',
#  'co',
#  'sap',
#  'fico',
#  'profitability',
#  'analysis',
#  'ap',
#  'profit',
#  'project',
#  'management',
#  'product',
#  'engineering',
#  'product',
#  'development',
#  'sql',
#  'excel',
#  'powerpoint',
#  'r',
#  'vba',
#  'mysql',
#  'python',
#  'data',
#  'analysis',
#  'data',
#  'entry',
#  'operation',
#  'typing',
#  'excel',
#  'notepad',
#  'freelancing',
#  'content',
#  'writing',
#  'accounting',
#  'book',
#  'keeping',
#  'reconciliation',
#  'verilog',
#  'vhdl',
#  'rtl',
#  'compiler',
#  'dft',
#  'design',
#  'engineering',
#  'failure',
#  'analysis',
#  'invoice',
#  'processing',
#  'vendor',
#  'management',
#  'bank',
#  'reconciliation',
#  'endeca',
#  'atg',
#  'commerce',
#  'atg',
#  'e',
#  'commerce',
#  'java',
#  'atg',
#  'atg',
#  'implementation',
#  'sql',
#  'multithreading',
#  'ooad',
#  'coding',
#  'debugging',
#  'investment',
#  'banking',
#  'spark',
#  'hive',
#  'hadoop',
#  'scala',
#  'java',
#  'big',
#  'data',
#  'machine',
#  'learning',
#  'python',
#  'rest',
#  'new',
#  'business',
#  'development',
#  'corporate',
#  'strategy',
#  'strategic',
#  'planning',
#  'financial',
#  'application',
#  'development',
#  'senior',
#  'analyst',
#  'neural',
#  'networks',
#  'r',
#  'python',
#  'big',
#  'data',
#  'analytics',
#  'data',
#  'analysis',
#  'deep',
#  'learning',
#  'machine',
#  'learning',
#  'text',
#  'mining',
#  'computer',
#  'vision',
#  'analytics',
#  'sales',
#  'management',
#  'business',
#  'development',
#  'management',
#  'lead',
#  'generation',
#  'presales',
#  'digital',
#  'marketing',
#  'digital',
#  'strategy',
#  'rfp',
#  'sales',
#  'alliances',
#  'analytics',
#  'manager',
#  'analytics',
#  'python',
#  'consulting',
#  'marketing',
#  'analytics',
#  'analytics',
#  'business',
#  'operations',
#  'business',
#  'process',
#  'data',
#  'modeling',
#  'portfolio',
#  'manager',
#  'wealth',
#  'manager',
#  'wealth',
#  'advisor',
#  'investment',
#  'advisor',
#  'marketing',
#  'communication',
#  'brand',
#  'management',
#  'atl',
#  'btl',
#  'social',
#  'media',
#  'marketing',
#  'oracle',
#  'telecom',
#  'business',
#  'analysis',
#  'togaf',
#  'documentation',
#  'tools',
#  'pega',
#  'prpc',
#  'java',
#  'bpm',
#  'application',
#  'development',
#  'business',
#  'rules',
#  'sap',
#  'bi',
#  'ui',
#  'development',
#  'business',
#  'process',
#  'outsourcing',
#  'analytical',
#  'liquidity',
#  'treasury',
#  'treasury',
#  'operations',
#  'forex',
#  'operations',
#  'global',
#  'procurement',
#  'purchase',
#  'management',
#  'sourcing',
#  'negotiation',
#  'detailing',
#  'communication',
#  'skills',
#  'data',
#  'migration',
#  'business',
#  'analysis',
#  'project',
#  'management',
#  'project',
#  'delivery',
#  'solution',
#  'architecting',
#  'agile',
#  'debugging',
#  'business',
#  'process',
#  'outsourcing',
#  'operations',
#  'pwd',
#  'j',
#  'ee',
#  'analytical',
#  'spark',
#  'project',
#  'management',
#  'big',
#  'data',
#  'rfps',
#  'solution',
#  'design',
#  'ar',
#  'calling',
#  'ar',
#  'analyst',
#  'accounts',
#  'receivable',
#  'revenue',
#  'cycle',
#  'management',
#  'data',
#  'analysis',
#  'outsourcing',
#  'operations',
#  'continuous',
#  'improvement',
#  'erp',
#  'functional',
#  'functional',
#  'consultancy',
#  'data',
#  'processing',
#  'data',
#  'management',
#  'project',
#  'management',
#  'technology',
#  'solutions',
#  'scope',
#  'solution',
#  'architecture',
#  'android',
#  'sql',
#  'software',
#  'architecture',
#  'software',
#  'design',
#  'design',
#  'patterns',
#  'financial',
#  'services',
#  'financial',
#  'analysis',
#  'business',
#  'analysis',
#  'balance',
#  'sheet',
#  'enterprise',
#  'risk',
#  'management',
#  'internal',
#  'audit',
#  'sox',
#  'auditing',
#  'business',
#  'analysis',
#  'business',
#  'process',
#  'outsourcing',
#  'business',
#  'strategy',
#  'digital',
#  'marketing',
#  'ecommerce',
#  'sales',
#  'brand',
#  'marketing',
#  'marketing',
#  'high',
#  'frequency',
#  'trading',
#  'market',
#  'making',
#  'quant',
#  'trader',
#  'market',
#  'maker',
#  'excel',
#  'data',
#  'analysis',
#  'sql',
#  'segmentation',
#  'data',
#  'analytics',
#  'statistics',
#  'business',
#  'development',
#  'b',
#  'b',
#  'sales',
#  'corporate',
#  'sales',
#  'marketing',
#  'planning',
#  'python',
#  'c',
#  'quantitative',
#  'research',
#  'statistical',
#  'analysis',
#  'statistics',
#  'advanced',
#  'analytics',
#  'statistical',
#  'modeling',
#  'linear',
#  'regression',
#  'statistics',
#  'python',
#  'machine',
#  'learning',
#  'digital',
#  'marketing',
#  'forecasting',
#  'deep',
#  'learning',
#  'natural',
#  'language',
#  'processing',
#  'machine',
#  'learning',
#  'nlp',
#  'python',
#  'process',
#  'improvement',
#  'auditing',
#  'analytical',
#  'interpersonal',
#  'skills',
#  'accounting',
#  'digital',
#  'marketing',
#  'promotions',
#  'segmentation',
#  'e',
#  'commerce',
#  'pay',
#  'per',
#  ...]

# %%
word_bag =  [] #word_bag of key_skills
for word in word_list:
    if word not in word_bag: # getting the unique words from word_list
        word_bag.append(word)
len(word_bag)
# Out:
# 4348

# %%
train['key_skills'] = re.sub('[^A-Za-z]+','',str(train['key_skills'])) # retaining the alphabets only in the key_skills column of the dataframe

# %%
for word in word_bag:
    train[word] = train['key_skills'].apply(lambda b: 1 if word in b else 0)  # creating the columns from the words in the word_bag

# %%
train.shape
# Out:
# (19802, 8309)

# %%
final_data = train.drop(train.columns[[0,1,2,3,4,5,6,8]],axis =1) # removing the experience, key_skills,job_description,job_desig,job_type,location from the dataframe
# Out:
# (19802, 8301)

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data =train_test_split(final_data,test_size=0.3,random_state=100) # splitting the dataframe into test and train
train_x = train_data.drop('salary',axis =1)
train_y = train_data['salary']
test_x = test_data.drop('salary',axis =1)
test_y = test_data['salary']

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
### Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier 
model_rf=RandomForestClassifier(random_state=100,n_estimators=300)
model_rf.fit(train_x,train_y)
pred=model_rf.predict(test_x)
print(accuracy_score(test_y,pred))
print(classification_report(test_y,pred))
# Out:
# 0.2250462885036189
#              precision    recall  f1-score   support
#
#        0to3       0.00      0.00      0.00       975
#      10to15       0.23      1.00      0.37      1337
#      15to25       0.00      0.00      0.00      1246
#      25to50       0.00      0.00      0.00       481
#        3to6       0.00      0.00      0.00       826
#       6to10       0.00      0.00      0.00      1076
#
# avg / total       0.05      0.23      0.08      5941
# C:\Users\Administrator\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
train_y.value_counts()
# Out:
# 10to15    3163
# 15to25    2879
# 6to10     2457
# 0to3      2270
# 3to6      1998
# 25to50    1094
# Name: salary, dtype: int64

# %%
### DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
model_dt=DecisionTreeClassifier(random_state = 100,max_depth =50)
model_dt.fit(train_x,train_y)
pred=model_dt.predict(test_x)
print(accuracy_score(test_y,pred))
print(classification_report(test_y,pred))
# Out:
# 0.2250462885036189
#              precision    recall  f1-score   support
#
#        0to3       0.00      0.00      0.00       975
#      10to15       0.23      1.00      0.37      1337
#      15to25       0.00      0.00      0.00      1246
#      25to50       0.00      0.00      0.00       481
#        3to6       0.00      0.00      0.00       826
#       6to10       0.00      0.00      0.00      1076
#
# avg / total       0.05      0.23      0.08      5941
# C:\Users\Administrator\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
### Logistic Regression Classifier
from sklearn.linear_model import LogisticRegression
model_lg = LogisticRegression()
model_lg.fit(train_x,train_y)
pred = model_lg.predict(test_x)
print(accuracy_score(test_y,pred))
print(classification_report(test_y,pred))
# Out:
# 0.2250462885036189
#              precision    recall  f1-score   support
#
#        0to3       0.00      0.00      0.00       975
#      10to15       0.23      1.00      0.37      1337
#      15to25       0.00      0.00      0.00      1246
#      25to50       0.00      0.00      0.00       481
#        3to6       0.00      0.00      0.00       826
#       6to10       0.00      0.00      0.00      1076
#
# avg / total       0.05      0.23      0.08      5941
# C:\Users\Administrator\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
